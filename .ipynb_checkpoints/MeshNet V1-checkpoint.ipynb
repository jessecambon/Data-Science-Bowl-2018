# %% [markdown]
# Source: https://www.kaggle.com/ahassaine/pure-image-processing-lb-0-274/code

# %% [markdown]
# # Libraries and Global Parameters

# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.util import img_as_bool, img_as_uint, img_as_ubyte
from skimage.transform import resize
#import skimage
#import glob
import random
from random import randint #, shuffle

from keras import regularizers
from keras.models import Model, load_model
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, Dense, \
    UpSampling2D, BatchNormalization, add, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras import backend as K
from keras.losses import binary_crossentropy

model_checkpoint_file='meshnet_ensemble_v1.h5'

# Root folders for test and training data
train_root = "./stage1_train"
test_root = "./stage1_test"

# Size we resize all images to
#image_size = (128,128)

img_height = 128
img_width = 128

# %% [markdown]
# # Preparing the Data

# %%
## Import Training Data Images 
train_dirs = os.listdir(train_root)
train_filenames=[os.path.join(train_root,file_id) + "/images/"+file_id+".png" for file_id in train_dirs]
# Convert to B&W inline
#train_images=[cv2.cvtColor(cv2.imread(imagefile),cv2.COLOR_BGR2GRAY) for imagefile in train_filenames]
train_images=[img_as_ubyte(imread(imagefile,as_grey=True)) for imagefile in train_filenames]

# Use this instead if you want color images
#train_images=[imread(imagefile) for imagefile in train_filenames]
# Out:
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
## Import Training Masks
# this takes longer than the training images because we have to
# combine a lot of mask files

# This function creates a single combined mask image 
# when given a list of masks
# Probably a computationally faster way to do this...
def collapse_masks(mask_list):
    for i, mask_file in enumerate(mask_list):        
        if i != 0:
            # combine mask with previous mask in list 
            mask = np.maximum(mask, imread(os.path.join(train_root,mask_file)))
        else:
            # read first mask in
            mask = imread(os.path.join(train_root,mask_file))
    
    return img_as_ubyte(mask)

# Import all the masks
train_mask_dirs = [ os.path.join(path, 'masks') for path in os.listdir(train_root) ]
train_mask_files = [ [os.path.join(dir,file) for file in os.listdir(os.path.join(train_root,dir)) ]  for dir in train_mask_dirs]

#def collapse_masks(mask_list):
#    for i, mask_file in enumerate(mask_list):
#        print(i)
#        print(mask_file)
        
#testing = [collapse_masks(mask_files) for mask_files in train_mask_files]

# Divide output of each mask by 255 to make a 1/0 binary mask
train_masks = [ collapse_masks(mask_files) for mask_files in train_mask_files ]

# %% [markdown]
# # Computer Vision Technique

# %%
def comp_viz_mask(img):
    #green channel happends to produce slightly better results
    #than the grayscale image and other channels
   # img_gray=img_rgb[:,:,1]#cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
    #morphological opening (size tuned on training data)
    circle7=cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(7,7))
    img_open=cv2.morphologyEx(img, cv2.MORPH_OPEN, circle7)
    #Otsu thresholding
    img_th=cv2.threshold(img_open,0,255,cv2.THRESH_OTSU)[1]
    #Invert the image in case the objects of interest are in the dark side
    if(np.sum(img_th==255)>np.sum(img_th==0)):
        img_th=cv2.bitwise_not(img_th)
    #second morphological opening (on binary image this time)
    bin_open=cv2.morphologyEx(img_th, cv2.MORPH_OPEN, circle7) 
    #connected components
    cc=cv2.connectedComponents(bin_open)[1]
    #cc=segment_on_dt(bin_open,20)
    return cc # convert to 1/0

# %%
train_cv2_masks = [ comp_viz_mask(image).astype(bool) for image in train_images ]

# %%
train_v2_masks[0].dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-7f52c83b31c9> in <module>()
# ----> 1 train_v2_masks[0].dtype
#
# NameError: name 'train_v2_masks' is not defined

# %%
train_masks[0].max()

# %%
# Plot images side by side for a list of datasets
def plot_side_by_side(ds_list,image_num):
    #print('Image #: ' + str(image_num) + '. Image Sizes: ' + str(image_ds[image_num].shape) + ' ' + str(mask_ds[image_num].shape))
    fig = plt.figure(figsize=(20,10))

    for i in range(len(ds_list)):
        ax1 = fig.add_subplot(1,len(ds_list),i+1)
        ax1.imshow(ds_list[i][image_num])

    plt.show()
    
# Plots random corresponding images and masks
def plot_check(ds_list,rand_imgs=None,img_nums=None):
    if rand_imgs != None:
        for i in range(rand_imgs):
            plot_side_by_side(ds_list, randint(0,len(ds_list[0])-1))
    if img_nums != None:
        for i in range(len(img_nums)):
            plot_side_by_side(ds_list,img_nums[i])
    
#plot_side_by_side(train_images,train_mask_images,38)
# Plot a few random images 
#plot_check(train_images,train_masks,rand_imgs=3)
plot_check([train_images,train_cv2_masks,train_masks],rand_imgs=3)
#plot_check(train_images,cv2_masks,rand_imgs=3)

#plot_check(train_images,train_mask_images,img_nums=[309])

# %%
# Resize everything
# Also do dtype conversions

# Scaling
resized_train_images = [ img_as_ubyte(resize(image,(img_width,img_height))) for image in train_images] 

resized_train_masks = [ img_as_bool(resize(image,(img_width,img_height))) for image in train_masks] 
resized_train_cv2_masks = [ img_as_bool(resize(image,(img_width,img_height))) for image in train_cv2_masks] 

#Croping

#crop_size=64

#resized_train_images = [ image[int(0.5*(image.shape[0]-crop_size)):int(0.5*(image.shape[0]+crop_size)),
#   int(0.5*(image.shape[1]-crop_size)):int(0.5*(image.shape[1]+crop_size))] for image in train_images] 

#resized_train_mask_images = [ image[int(0.5*(image.shape[0]-crop_size)):int(0.5*(image.shape[0]+crop_size)),
#   int(0.5*(image.shape[1]-crop_size)):int(0.5*(image.shape[1]+crop_size))] for image in train_mask_images]
# Out:
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# ...
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\595559\AppData\Local\Continuum\anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# check max pixel values
print(resized_train_images[309].max())
print(resized_train_images[16].max())
# Out:
# 87
# 170

# %%
# Check to see that my resizing and compression is screwing stuff up
rand_img_num = randint(0,len(train_images))
#plot_check(compressed_train_images,compressed_train_masks,img_nums=[rand_img_num])
#plot_check(train_images,train_mask_images,img_nums=[rand_img_num])

print('Original image and mask')
plot_check([train_images,train_cv2_masks,train_masks],img_nums=[492])
print('Resized image and mask')
plot_check([resized_train_images,resized_train_cv2_masks,resized_train_masks],img_nums=[492])

#plot_check(train_images,train_mask_images,img_nums=[664])
#print(train_images[664].max())
# Out:
# Original image and mask
# Resized image and mask

# %%
# Check to see that my resizing and compression is screwing stuff up
rand_img_num = randint(0,len(train_images))
#plot_check(compressed_train_images,compressed_train_masks,img_nums=[rand_img_num])
#plot_check(train_images,train_mask_images,img_nums=[rand_img_num])

print('Original image and mask')
plot_check(train_images,train_masks,img_nums=[492])
print('Resized image and mask')
plot_check(resized_train_images,resized_train_masks,img_nums=[492])

#plot_check(train_images,train_mask_images,img_nums=[664])
#print(train_images[664].max())
# Out:
# Original image and mask
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-4fa023ab23d2> in <module>()
#       5
#       6 print('Original image and mask')
# ----> 7 plot_check(train_images,train_masks,img_nums=[492])
#       8 print('Resized image and mask')
#       9 plot_check(resized_train_images,resized_train_masks,img_nums=[492])
#
# <ipython-input-47-46e92799dd44> in plot_check(ds_list, rand_imgs, img_nums)
#      13 def plot_check(ds_list,rand_imgs=None,img_nums=None):
#      14     if rand_imgs != None:
# ---> 15         for i in range(rand_imgs):
#      16             plot_side_by_side(ds_list, randint(0,len(ds_list[0])-1))
#      17     if img_nums != None:
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
# Reshape model inputs
#train_X = np.reshape(np.array(resized_train_images),(len(resized_train_images),img_height,img_width,1))

# Stack cv2 masks on top of images as a channel
train_X = np.reshape(np.stack((np.array(resized_train_images),np.array(resized_train_cv2_masks)),axis=3), \
                     (len(resized_train_images),img_height,img_width,2))
train_Y = np.reshape(np.array(resized_train_masks),(len(resized_train_masks),img_height,img_width,1))

# Check size of arrays we are inputting to model
# This is important! We need the datasets to be as 
# small as possible to reduce computation time
print(train_X.shape)
print(train_Y.shape)
print(train_X.nbytes)
print(train_Y.nbytes)
# Out:
# (670, 128, 128, 2)
# (670, 128, 128, 1)
# 21954560
# 10977280

# %%
# Check datatypes
print(train_Y[0].dtype)
print(train_X[0].dtype)

#train_X[0]
# Out:
# bool
# uint8

# %%
plot_check(np.squeeze(train_X,axis=3),np.squeeze(train_Y,axis=3),img_nums=[5,119,356,602])
plot_check(train_images,train_masks,img_nums=[5,119,356,602])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-513c3d6c9ccf> in <module>()
# ----> 1 plot_check(np.squeeze(train_X,axis=3),np.squeeze(train_Y,axis=3),img_nums=[5,119,356,602])
#       2 plot_check(train_images,train_masks,img_nums=[5,119,356,602])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in squeeze(a, axis)
#    1180     try:
#    1181         # First try to use the new axis= parameter
# -> 1182         return squeeze(axis=axis)
#    1183     except TypeError:
#    1184         # For backwards compatibility
#
# ValueError: cannot select an axis to squeeze out which has size not equal to one

# %%
train_X[602].max() # check max pixel value
# Out:
# 255

# %% [markdown]
# # Now Let's Build the Model

# %%
# Loss and metric functions for the neural net
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def create_block(x, filters=32, filter_size=(3, 3), activation='relu',dil_rate=(1,1),dropout_rate=0.15):
#    for i in range(n_block):
    x = Conv2D(filters, filter_size, padding='same', dilation_rate = dil_rate) (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x) 
    x = Dropout(dropout_rate) (x)
    return x


## master function for creating a net
def get_net(
        input_shape=(img_height, img_width,2),
        loss=bce_dice_loss,
        n_class=1
):
    inputs = Input(input_shape)
    
    # Create layers
    net_body = create_block(inputs)
    net_body = create_block(net_body)
    #net_body = create_block(net_body)  # this is an extra layer (compared to MeshNet paper) .. 
    net_body = create_block(net_body,dil_rate=(2,2))
    net_body = create_block(net_body,dil_rate=(4,4))
    net_body = create_block(net_body,dil_rate=(8,8))
    net_body = create_block(net_body,dil_rate=(16,16))
    net_body = create_block(net_body)
    # Sigmoid used since we are classifying pixels 1/0. Softmax used for multiclass
    classify = Conv2D(n_class,(1,1),activation='sigmoid') (net_body)
    
    #classify = Activation(activation='sigmoid') (net_body)
    #classify = Dense(1,activation='sigmoid') (net_body)

    model = Model(inputs=inputs, outputs=classify)
    model.compile(optimizer='Adam', loss=loss, metrics=[dice_coef, binary_crossentropy])

    return model

# %%
my_model = get_net()

# %%
print(my_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 128, 128, 2)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 128, 32)      608
# _________________________________________________________________
# activation_8 (Activation)    (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# activation_9 (Activation)    (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# activation_10 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# activation_11 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# activation_12 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# activation_13 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# activation_14 (Activation)   (None, 128, 128, 32)      0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 128, 128, 1)       33
# =================================================================
# Total params: 57,025
# Trainable params: 56,577
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
# Fit model

# learning rate decay https://keras.io/callbacks/#learningratescheduler 

# This function controls the learning rate based on the epoch
# must return a float
def scheduler(epoch):
    if epoch > 15:
        return float(0.0001) 
    elif epoch > 6:
        return float(0.001) 
    else:
        return float(0.01) 
    
change_lr = LearningRateScheduler(scheduler,verbose=1)
earlystopper = EarlyStopping(patience=10, verbose=1)
checkpointer = ModelCheckpoint(model_checkpoint_file, verbose=1, save_best_only=True)
reduce_plateau = ReduceLROnPlateau(monitor='val_loss', 
                           factor=0.5,
                           patience=4,
                           verbose=1,
                        #   min_lr=0.00001,
                            epsilon=0.001,
                           mode='auto') 
# verbose=2 => one line per epoch, 1 = progress bar

### Add an epsilon 
results = my_model.fit(train_X, train_Y, validation_split=0.1, batch_size=15, epochs=75, verbose=1, 
                       shuffle=True, callbacks=[change_lr, earlystopper, checkpointer, reduce_plateau])
# Out:
# Train on 603 samples, validate on 67 samples
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 1/75
# 600/603 [============================>.] - ETA: 4s - loss: 1.0346 - dice_coef: 0.5216 - binary_crossentropy: 0.4529
# Epoch 00001: val_loss improved from inf to 0.80559, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 871s 1s/step - loss: 1.0347 - dice_coef: 0.5212 - binary_crossentropy: 0.4530 - val_loss: 0.8056 - val_dice_coef: 0.6685 - val_binary_crossentropy: 0.4542
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 2/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.4961 - dice_coef: 0.7564 - binary_crossentropy: 0.2051
# Epoch 00002: val_loss improved from 0.80559 to 0.48440, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 866s 1s/step - loss: 0.4991 - dice_coef: 0.7542 - binary_crossentropy: 0.2060 - val_loss: 0.4844 - val_dice_coef: 0.7597 - val_binary_crossentropy: 0.2274
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 3/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.4087 - dice_coef: 0.7986 - binary_crossentropy: 0.1675
# Epoch 00003: val_loss did not improve
# 603/603 [==============================] - 848s 1s/step - loss: 0.4102 - dice_coef: 0.7975 - binary_crossentropy: 0.1678 - val_loss: 1.0804 - val_dice_coef: 0.4245 - val_binary_crossentropy: 0.5063
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 4/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.3657 - dice_coef: 0.8175 - binary_crossentropy: 0.1495
# Epoch 00004: val_loss improved from 0.48440 to 0.40149, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 843s 1s/step - loss: 0.3678 - dice_coef: 0.8162 - binary_crossentropy: 0.1501 - val_loss: 0.4015 - val_dice_coef: 0.8081 - val_binary_crossentropy: 0.1752
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 5/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.3410 - dice_coef: 0.8318 - binary_crossentropy: 0.1416
# Epoch 00005: val_loss improved from 0.40149 to 0.34377, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 845s 1s/step - loss: 0.3406 - dice_coef: 0.8319 - binary_crossentropy: 0.1414 - val_loss: 0.3438 - val_dice_coef: 0.8282 - val_binary_crossentropy: 0.1612
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 6/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.3133 - dice_coef: 0.8457 - binary_crossentropy: 0.1299
# Epoch 00006: val_loss improved from 0.34377 to 0.32291, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 841s 1s/step - loss: 0.3136 - dice_coef: 0.8456 - binary_crossentropy: 0.1301 - val_loss: 0.3229 - val_dice_coef: 0.8390 - val_binary_crossentropy: 0.1486
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 7/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2863 - dice_coef: 0.8602 - binary_crossentropy: 0.1194
# Epoch 00007: val_loss improved from 0.32291 to 0.25548, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 838s 1s/step - loss: 0.2858 - dice_coef: 0.8605 - binary_crossentropy: 0.1192 - val_loss: 0.2555 - val_dice_coef: 0.8690 - val_binary_crossentropy: 0.1039
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2669 - dice_coef: 0.8682 - binary_crossentropy: 0.1087
# Epoch 00008: val_loss did not improve
# 603/603 [==============================] - 840s 1s/step - loss: 0.2682 - dice_coef: 0.8678 - binary_crossentropy: 0.1097 - val_loss: 0.2688 - val_dice_coef: 0.8609 - val_binary_crossentropy: 0.1110
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2672 - dice_coef: 0.8687 - binary_crossentropy: 0.1105
# Epoch 00009: val_loss did not improve
# 603/603 [==============================] - 837s 1s/step - loss: 0.2669 - dice_coef: 0.8689 - binary_crossentropy: 0.1104 - val_loss: 0.2677 - val_dice_coef: 0.8604 - val_binary_crossentropy: 0.1078
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2681 - dice_coef: 0.8681 - binary_crossentropy: 0.1096
# Epoch 00010: val_loss did not improve
# 603/603 [==============================] - 843s 1s/step - loss: 0.2673 - dice_coef: 0.8684 - binary_crossentropy: 0.1093 - val_loss: 0.2772 - val_dice_coef: 0.8564 - val_binary_crossentropy: 0.1146
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2695 - dice_coef: 0.8678 - binary_crossentropy: 0.1125
# Epoch 00011: val_loss did not improve
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 603/603 [==============================] - 839s 1s/step - loss: 0.2694 - dice_coef: 0.8679 - binary_crossentropy: 0.1124 - val_loss: 0.2720 - val_dice_coef: 0.8577 - val_binary_crossentropy: 0.1099
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2589 - dice_coef: 0.8740 - binary_crossentropy: 0.1083
# Epoch 00012: val_loss did not improve
# 603/603 [==============================] - 842s 1s/step - loss: 0.2585 - dice_coef: 0.8742 - binary_crossentropy: 0.1080 - val_loss: 0.2600 - val_dice_coef: 0.8635 - val_binary_crossentropy: 0.1042
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2562 - dice_coef: 0.8735 - binary_crossentropy: 0.1055
# Epoch 00013: val_loss improved from 0.25548 to 0.25136, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 845s 1s/step - loss: 0.2568 - dice_coef: 0.8732 - binary_crossentropy: 0.1058 - val_loss: 0.2514 - val_dice_coef: 0.8686 - val_binary_crossentropy: 0.1012
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2572 - dice_coef: 0.8737 - binary_crossentropy: 0.1066
# Epoch 00014: val_loss did not improve
# 603/603 [==============================] - 842s 1s/step - loss: 0.2568 - dice_coef: 0.8739 - binary_crossentropy: 0.1063 - val_loss: 0.2634 - val_dice_coef: 0.8611 - val_binary_crossentropy: 0.1055
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2581 - dice_coef: 0.8714 - binary_crossentropy: 0.1050
# Epoch 00015: val_loss did not improve
# 603/603 [==============================] - 841s 1s/step - loss: 0.2578 - dice_coef: 0.8716 - binary_crossentropy: 0.1050 - val_loss: 0.2689 - val_dice_coef: 0.8584 - val_binary_crossentropy: 0.1081
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2510 - dice_coef: 0.8755 - binary_crossentropy: 0.1027
# Epoch 00016: val_loss improved from 0.25136 to 0.23951, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 844s 1s/step - loss: 0.2509 - dice_coef: 0.8755 - binary_crossentropy: 0.1027 - val_loss: 0.2395 - val_dice_coef: 0.8739 - val_binary_crossentropy: 0.0942
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 17/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2454 - dice_coef: 0.8788 - binary_crossentropy: 0.0999
# Epoch 00017: val_loss did not improve
# 603/603 [==============================] - 842s 1s/step - loss: 0.2463 - dice_coef: 0.8784 - binary_crossentropy: 0.1004 - val_loss: 0.2415 - val_dice_coef: 0.8725 - val_binary_crossentropy: 0.0954
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 18/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2451 - dice_coef: 0.8795 - binary_crossentropy: 0.1007
# Epoch 00018: val_loss did not improve
# 603/603 [==============================] - 842s 1s/step - loss: 0.2444 - dice_coef: 0.8799 - binary_crossentropy: 0.1004 - val_loss: 0.2423 - val_dice_coef: 0.8722 - val_binary_crossentropy: 0.0962
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 19/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2519 - dice_coef: 0.8748 - binary_crossentropy: 0.1019
# Epoch 00019: val_loss did not improve
# 603/603 [==============================] - 842s 1s/step - loss: 0.2512 - dice_coef: 0.8751 - binary_crossentropy: 0.1017 - val_loss: 0.2455 - val_dice_coef: 0.8703 - val_binary_crossentropy: 0.0982
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 20/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2550 - dice_coef: 0.8732 - binary_crossentropy: 0.1043
# Epoch 00020: val_loss did not improve
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 603/603 [==============================] - 839s 1s/step - loss: 0.2565 - dice_coef: 0.8719 - binary_crossentropy: 0.1044 - val_loss: 0.2408 - val_dice_coef: 0.8730 - val_binary_crossentropy: 0.0961
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 21/75
# 600/603 [============================>.] - ETA: 4s - loss: 0.2479 - dice_coef: 0.8773 - binary_crossentropy: 0.1009
# Epoch 00021: val_loss did not improve
# 603/603 [==============================] - 839s 1s/step - loss: 0.2484 - dice_coef: 0.8772 - binary_crossentropy: 0.1012 - val_loss: 0.2405 - val_dice_coef: 0.8733 - val_binary_crossentropy: 0.0962
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 22/75
# 600/603 [============================>.] - ETA: 3s - loss: 0.2436 - dice_coef: 0.8809 - binary_crossentropy: 0.1002
# Epoch 00022: val_loss did not improve
# 603/603 [==============================] - 798s 1s/step - loss: 0.2439 - dice_coef: 0.8808 - binary_crossentropy: 0.1004 - val_loss: 0.2410 - val_dice_coef: 0.8727 - val_binary_crossentropy: 0.0965
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 23/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2451 - dice_coef: 0.8797 - binary_crossentropy: 0.1009
# Epoch 00023: val_loss improved from 0.23951 to 0.23723, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 455s 754ms/step - loss: 0.2457 - dice_coef: 0.8793 - binary_crossentropy: 0.1011 - val_loss: 0.2372 - val_dice_coef: 0.8747 - val_binary_crossentropy: 0.0946
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 24/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2429 - dice_coef: 0.8804 - binary_crossentropy: 0.0995
# Epoch 00024: val_loss did not improve
# 603/603 [==============================] - 452s 749ms/step - loss: 0.2438 - dice_coef: 0.8801 - binary_crossentropy: 0.1002 - val_loss: 0.2381 - val_dice_coef: 0.8742 - val_binary_crossentropy: 0.0952
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 25/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2472 - dice_coef: 0.8778 - binary_crossentropy: 0.1009
# Epoch 00025: val_loss did not improve
# 603/603 [==============================] - 454s 753ms/step - loss: 0.2493 - dice_coef: 0.8760 - binary_crossentropy: 0.1010 - val_loss: 0.2404 - val_dice_coef: 0.8730 - val_binary_crossentropy: 0.0965
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 26/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2468 - dice_coef: 0.8796 - binary_crossentropy: 0.1024
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 452s 750ms/step - loss: 0.2476 - dice_coef: 0.8794 - binary_crossentropy: 0.1031 - val_loss: 0.2407 - val_dice_coef: 0.8727 - val_binary_crossentropy: 0.0969
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 27/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2470 - dice_coef: 0.8770 - binary_crossentropy: 0.1006
# Epoch 00027: val_loss did not improve
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 603/603 [==============================] - 453s 752ms/step - loss: 0.2468 - dice_coef: 0.8770 - binary_crossentropy: 0.1004 - val_loss: 0.2377 - val_dice_coef: 0.8743 - val_binary_crossentropy: 0.0950
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 28/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2447 - dice_coef: 0.8790 - binary_crossentropy: 0.0998
# Epoch 00028: val_loss improved from 0.23723 to 0.23699, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 452s 750ms/step - loss: 0.2455 - dice_coef: 0.8787 - binary_crossentropy: 0.1003 - val_loss: 0.2370 - val_dice_coef: 0.8750 - val_binary_crossentropy: 0.0946
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 29/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2478 - dice_coef: 0.8780 - binary_crossentropy: 0.1021
# Epoch 00029: val_loss did not improve
# 603/603 [==============================] - 453s 751ms/step - loss: 0.2489 - dice_coef: 0.8776 - binary_crossentropy: 0.1028 - val_loss: 0.2408 - val_dice_coef: 0.8727 - val_binary_crossentropy: 0.0965
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 30/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2438 - dice_coef: 0.8813 - binary_crossentropy: 0.1008
# Epoch 00030: val_loss did not improve
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 603/603 [==============================] - 452s 749ms/step - loss: 0.2446 - dice_coef: 0.8811 - binary_crossentropy: 0.1015 - val_loss: 0.2391 - val_dice_coef: 0.8736 - val_binary_crossentropy: 0.0962
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 31/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2510 - dice_coef: 0.8759 - binary_crossentropy: 0.1032
# Epoch 00031: val_loss did not improve
# 603/603 [==============================] - 454s 753ms/step - loss: 0.2503 - dice_coef: 0.8763 - binary_crossentropy: 0.1028 - val_loss: 0.2435 - val_dice_coef: 0.8709 - val_binary_crossentropy: 0.0978
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 32/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2395 - dice_coef: 0.8828 - binary_crossentropy: 0.0982
# Epoch 00032: val_loss did not improve
# 603/603 [==============================] - 454s 753ms/step - loss: 0.2414 - dice_coef: 0.8819 - binary_crossentropy: 0.0991 - val_loss: 0.2374 - val_dice_coef: 0.8745 - val_binary_crossentropy: 0.0952
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 33/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2430 - dice_coef: 0.8808 - binary_crossentropy: 0.1001
# Epoch 00033: val_loss did not improve
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 603/603 [==============================] - 452s 750ms/step - loss: 0.2435 - dice_coef: 0.8804 - binary_crossentropy: 0.1000 - val_loss: 0.2422 - val_dice_coef: 0.8717 - val_binary_crossentropy: 0.0976
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 34/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2478 - dice_coef: 0.8796 - binary_crossentropy: 0.1036
# Epoch 00034: val_loss did not improve
# 603/603 [==============================] - 451s 747ms/step - loss: 0.2482 - dice_coef: 0.8793 - binary_crossentropy: 0.1037 - val_loss: 0.2370 - val_dice_coef: 0.8746 - val_binary_crossentropy: 0.0947
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 35/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2450 - dice_coef: 0.8802 - binary_crossentropy: 0.1015
# Epoch 00035: val_loss improved from 0.23699 to 0.23433, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 451s 749ms/step - loss: 0.2468 - dice_coef: 0.8789 - binary_crossentropy: 0.1020 - val_loss: 0.2343 - val_dice_coef: 0.8762 - val_binary_crossentropy: 0.0932
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 36/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2460 - dice_coef: 0.8784 - binary_crossentropy: 0.1009
# Epoch 00036: val_loss improved from 0.23433 to 0.23316, saving model to meshnet_ensemble_v1.h5
# 603/603 [==============================] - 451s 748ms/step - loss: 0.2454 - dice_coef: 0.8786 - binary_crossentropy: 0.1006 - val_loss: 0.2332 - val_dice_coef: 0.8769 - val_binary_crossentropy: 0.0926
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 37/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2398 - dice_coef: 0.8810 - binary_crossentropy: 0.0975
# Epoch 00037: val_loss did not improve
# 603/603 [==============================] - 452s 749ms/step - loss: 0.2392 - dice_coef: 0.8814 - binary_crossentropy: 0.0972 - val_loss: 0.2346 - val_dice_coef: 0.8759 - val_binary_crossentropy: 0.0938
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 38/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2413 - dice_coef: 0.8817 - binary_crossentropy: 0.0997
# Epoch 00038: val_loss did not improve
# 603/603 [==============================] - 453s 751ms/step - loss: 0.2416 - dice_coef: 0.8815 - binary_crossentropy: 0.0995 - val_loss: 0.2345 - val_dice_coef: 0.8761 - val_binary_crossentropy: 0.0938
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 39/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2402 - dice_coef: 0.8815 - binary_crossentropy: 0.0980
# Epoch 00039: val_loss did not improve
# 603/603 [==============================] - 456s 756ms/step - loss: 0.2410 - dice_coef: 0.8814 - binary_crossentropy: 0.0987 - val_loss: 0.2374 - val_dice_coef: 0.8743 - val_binary_crossentropy: 0.0954
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2447 - dice_coef: 0.8788 - binary_crossentropy: 0.1000
# Epoch 00040: val_loss did not improve
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 603/603 [==============================] - 452s 749ms/step - loss: 0.2453 - dice_coef: 0.8783 - binary_crossentropy: 0.1000 - val_loss: 0.2388 - val_dice_coef: 0.8734 - val_binary_crossentropy: 0.0959
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2370 - dice_coef: 0.8825 - binary_crossentropy: 0.0967
# Epoch 00041: val_loss did not improve
# 603/603 [==============================] - 453s 751ms/step - loss: 0.2366 - dice_coef: 0.8828 - binary_crossentropy: 0.0965 - val_loss: 0.2397 - val_dice_coef: 0.8729 - val_binary_crossentropy: 0.0961
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 42/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2427 - dice_coef: 0.8805 - binary_crossentropy: 0.0995
# Epoch 00042: val_loss did not improve
# 603/603 [==============================] - 460s 763ms/step - loss: 0.2428 - dice_coef: 0.8806 - binary_crossentropy: 0.0997 - val_loss: 0.2359 - val_dice_coef: 0.8750 - val_binary_crossentropy: 0.0945
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 43/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2384 - dice_coef: 0.8822 - binary_crossentropy: 0.0976
# Epoch 00043: val_loss did not improve
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 603/603 [==============================] - 479s 794ms/step - loss: 0.2384 - dice_coef: 0.8821 - binary_crossentropy: 0.0976 - val_loss: 0.2365 - val_dice_coef: 0.8749 - val_binary_crossentropy: 0.0949
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 44/75
# 600/603 [============================>.] - ETA: 2s - loss: 0.2437 - dice_coef: 0.8792 - binary_crossentropy: 0.1003
# Epoch 00044: val_loss did not improve
# 603/603 [==============================] - 472s 783ms/step - loss: 0.2442 - dice_coef: 0.8790 - binary_crossentropy: 0.1006 - val_loss: 0.2336 - val_dice_coef: 0.8764 - val_binary_crossentropy: 0.0939
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 45/75
# 540/603 [=========================>....] - ETA: 49s - loss: 0.2390 - dice_coef: 0.8819 - binary_crossentropy: 0.0975
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-77-df6665b8b509> in <module>()
#      27 ### Add an epsilon
#      28 results = my_model.fit(train_X, train_Y, validation_split=0.1, batch_size=15, epochs=75, verbose=1,
# ---> 29                        shuffle=True, callbacks=[change_lr, earlystopper, checkpointer, reduce_plateau])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1667                               initial_epoch=initial_epoch,
#    1668                               steps_per_epoch=steps_per_epoch,
# -> 1669                               validation_steps=validation_steps)
#    1670
#    1671     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1204                         ins_batch[i] = ins_batch[i].toarray()
#    1205
# -> 1206                     outs = f(ins_batch)
#    1207                     if not isinstance(outs, list):
#    1208                         outs = [outs]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
#Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001.
#Epoch 13/75
#600/603 [============================>.] - ETA: 1s - loss: 0.2774 - dice_coef: 0.8625 - binary_crossentropy: 0.1149
#Epoch 00013: val_loss improved from 0.25185 to 0.24854, saving model to bw_model_v8.h5
#603/603 [==============================] - 221s 367ms/step - loss: 0.2768 - dice_coef: 0.8628 - binary_crossentropy: 0.1146 - val_loss: 0.2485 - val_dice_coef: 0.8691 - val_binary_crossentropy: 0.1000
#Epoch 00017: LearningRateScheduler reducing learning rate to 0.0001.
#Epoch 17/75
#600/603 [============================>.] - ETA: 1s - loss: 0.2818 - dice_coef: 0.8604 - binary_crossentropy: 0.1164
#Epoch 00017: val_loss did not improve
#603/603 [==============================] - 217s 360ms/step - loss: 0.2842 - dice_coef: 0.8593 - binary_crossentropy: 0.1176 - val_loss: 0.2480 - val_dice_coef: 0.8686 - val_binary_crossentropy: 0.1002


# Make predictions
final_model = load_model(model_checkpoint_file, custom_objects={'dice_coef': dice_coef, 'bce_dice_loss':bce_dice_loss})
#preds_train = final_model.predict(train_X[:int(train_X.shape[0]*0.9)], verbose=1)
#preds_val = final_model.predict(train_X[int(train_X.shape[0]*0.9):], verbose=1)

preds_train = final_model.predict(train_X, verbose=1)

preds_train_t = (preds_train > 0.5).astype(np.uint8)
#preds_val_t = (preds_val > 0.5).astype(np.uint8)

# %%
rand_img_num = randint(0,len(train_images))
#plot_check(compressed_train_images,compressed_train_masks,img_nums=[rand_img_num])
#plot_check(train_images,train_mask_images,img_nums=[rand_img_num])

print('Original Image and Mask')
plot_check(train_images,train_mask_images,img_nums=[194])
print('Resized Image and Resized Mask')
plot_check(resized_train_images,resized_train_masks,img_nums=[194])
print('Prediction v. Mask')
plot_check(np.squeeze(preds_train_t,axis=3),resized_train_masks,img_nums=[194])
# Out:
# Original Image and Mask
# Image #: 194. Image Sizes: (360, 360) (360, 360)
# Resized Image and Resized Mask
# Image #: 194. Image Sizes: (128, 128) (128, 128)
# Prediction v. Mask
# Image #: 194. Image Sizes: (128, 128) (128, 128)

# %%
Ideas
 - Experiment with compression of training data. Am I preserving as much detail
    as I can in dtype np.uint8 (values of 0 to 255) ?
- Color vs B&W?
- Combine mask and prediction images to show false positives and negatives
- What is the best resizing method? Reflect??
- Put computer vision / threshold method output as an input to neural net
- Output intermediate layers for inspection
- Crop images to train networks faster for testing ??
- Take random crops of images to create, and then combine outputs in the end
- Is combining the masks really the best thing to do? Should I be keeping the individual cells separate?
- Pseudo-labelled data
