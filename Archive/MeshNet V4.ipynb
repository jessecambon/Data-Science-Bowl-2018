# %% [markdown]
# Source: https://www.kaggle.com/ahassaine/pure-image-processing-lb-0-274/code

# %% [markdown]
# # Libraries and Global Parameters

# %%
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.util import img_as_bool, img_as_uint, img_as_ubyte
from skimage.transform import resize
#import skimage
#import glob
import random
from random import randint #, shuffle
from skimage.morphology import label


from keras import regularizers
from keras.models import Model, load_model
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, Dense, \
    UpSampling2D, BatchNormalization, add, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras import backend as K
from keras.losses import binary_crossentropy, sparse_categorical_crossentropy

model_checkpoint_file='meshnet_v4.h5'

# Root folders for test and training data
train_root = "./stage1_train"
test_root = "./stage1_test"

# Size we resize all images to
#image_size = (128,128)

img_height = 128
img_width = 128

import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Preparing the Data

# %%
## Import Training Data Images 
train_dirs = os.listdir(train_root)
train_filenames=[os.path.join(train_root,file_id) + "/images/"+file_id+".png" for file_id in train_dirs]
# Convert to B&W inline
#train_images=[cv2.cvtColor(cv2.imread(imagefile),cv2.COLOR_BGR2GRAY) for imagefile in train_filenames]
train_images=[imread(imagefile,as_grey=True) for imagefile in train_filenames]

# Use this instead if you want color images
#train_images=[imread(imagefile) for imagefile in train_filenames]

# %%
## Import Training Masks
# this takes longer than the training images because we have to
# combine a lot of mask files

# This function creates a single combined mask image 
# when given a list of masks
# Probably a computationally faster way to do this...
def collapse_masks(mask_list):
    for i, mask_file in enumerate(mask_list):        
        if i != 0:
            # combine mask with previous mask in list 
            mask = np.maximum(mask, imread(os.path.join(train_root,mask_file)))
        else:
            # read first mask in
            mask = imread(os.path.join(train_root,mask_file))
    
    return mask

# Import all the masks
train_mask_dirs = [ os.path.join(path, 'masks') for path in os.listdir(train_root) ]
train_mask_files = [ [os.path.join(dir,file) for file in os.listdir(os.path.join(train_root,dir)) ]  for dir in train_mask_dirs]

#def collapse_masks(mask_list):
#    for i, mask_file in enumerate(mask_list):
#        print(i)
#        print(mask_file)
        
#testing = [collapse_masks(mask_files) for mask_files in train_mask_files]

# Divide output of each mask by 255 to make a 1/0 binary mask
train_masks = [ collapse_masks(mask_files) for mask_files in train_mask_files ]

# %% [markdown]
# # Computer Vision Technique

# %%
def comp_viz_mask(img):
    #green channel happends to produce slightly better results
    #than the grayscale image and other channels
   # img_gray=img_rgb[:,:,1]#cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
    #morphological opening (size tuned on training data)
    circle7=cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(7,7))
    img_open=cv2.morphologyEx(img, cv2.MORPH_OPEN, circle7)
    #Otsu thresholding
    img_th=cv2.threshold(img_open,0,255,cv2.THRESH_OTSU)[1]
    #Invert the image in case the objects of interest are in the dark side
    if(np.sum(img_th==255)>np.sum(img_th==0)):
        img_th=cv2.bitwise_not(img_th)
    #second morphological opening (on binary image this time)
    bin_open=cv2.morphologyEx(img_th, cv2.MORPH_OPEN, circle7) 
    #connected components
    cc=cv2.connectedComponents(bin_open)[1]
    #cc=segment_on_dt(bin_open,20)
    return cc # convert to 1/0

# %%
# Plot images side by side for a list of datasets
def plot_side_by_side(ds_list,image_num):
    #print('Image #: ' + str(image_num) + '. Image Sizes: ' + str(image_ds[image_num].shape) + ' ' + str(mask_ds[image_num].shape))
    fig = plt.figure(figsize=(20,10))

    for i in range(len(ds_list)):
        ax1 = fig.add_subplot(1,len(ds_list),i+1)
        ax1.imshow(ds_list[i][image_num])

    plt.show()
    
# Plots random corresponding images and masks
def plot_check(ds_list,rand_imgs=None,img_nums=None):
    if rand_imgs != None:
        for i in range(rand_imgs):
            plot_side_by_side(ds_list, randint(0,len(ds_list[0])-1))
    if img_nums != None:
        for i in range(len(img_nums)):
            plot_side_by_side(ds_list,img_nums[i])
    
#plot_side_by_side(train_images,train_mask_images,38)
# Plot a few random images 
#plot_check(train_images,train_masks,rand_imgs=3)
plot_check([train_images,train_masks],rand_imgs=1)
#plot_check(train_images,cv2_masks,rand_imgs=3)

#plot_check(train_images,train_mask_images,img_nums=[309])

# %%
# Resize everything
# Also do dtype conversions

# Scaling
resized_train_images = [ img_as_ubyte(resize(image,(img_width,img_height))) for image in train_images] 

resized_train_masks = [ img_as_bool(resize(image,(img_width,img_height))) for image in train_masks] 
#resized_train_cv2_masks = [ img_as_bool(resize(image,(img_width,img_height))) for image in train_cv2_masks] 

#Croping

#crop_size=64

#resized_train_images = [ image[int(0.5*(image.shape[0]-crop_size)):int(0.5*(image.shape[0]+crop_size)),
#   int(0.5*(image.shape[1]-crop_size)):int(0.5*(image.shape[1]+crop_size))] for image in train_images] 

#resized_train_mask_images = [ image[int(0.5*(image.shape[0]-crop_size)):int(0.5*(image.shape[0]+crop_size)),
#   int(0.5*(image.shape[1]-crop_size)):int(0.5*(image.shape[1]+crop_size))] for image in train_mask_images]

# %%
# check max pixel values
print(resized_train_images[309].max())
print(resized_train_images[16].max())
# Out:
# 87
# 170

# %%
# Reshape model inputs
train_X = np.reshape(np.array(resized_train_images),(len(resized_train_images),img_height,img_width,1))

# Stack cv2 masks on top of images as a channel
#train_X = np.reshape(np.stack((np.array(resized_train_images),np.array(resized_train_cv2_masks)),axis=3), \
#                     (len(resized_train_images),img_height,img_width,2))
train_Y = np.reshape(np.array(resized_train_masks),(len(resized_train_masks),img_height,img_width,1))

# Check size of arrays we are inputting to model
# This is important! We need the datasets to be as 
# small as possible to reduce computation time
print(train_X.shape)
print(train_Y.shape)
print(train_X.nbytes)
print(train_Y.nbytes)
# Out:
# (670, 128, 128, 1)
# (670, 128, 128, 1)
# 10977280
# 10977280

# %%
# Check datatypes
print(train_Y.dtype)
print(train_X.dtype)

#train_X[0]

# %% [markdown]
# # Now Let's Build the Model

# %%
# Loss and metric functions for the neural net
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def create_block(x, filters=20, filter_size=(3, 3), activation='relu',dil_rate=1,dropout_rate=0.1):
#    for i in range(n_block):
    x = Conv2D(filters, filter_size, padding='same', activation='relu', dilation_rate = dil_rate) (x)
    x = BatchNormalization() (x) 
    x = Dropout(dropout_rate) (x)
    return x


## master function for creating a net
def get_net(
        input_shape=(img_height, img_width,1),
        loss=binary_crossentropy,
        n_class=1
):
    inputs = Input(input_shape)
    
    # Create layers
    net_body = create_block(inputs)
    net_body = create_block(net_body)
    net_body = create_block(net_body)
    net_body = create_block(net_body,dil_rate=2)
    net_body = create_block(net_body,dil_rate=4)
    net_body = create_block(net_body,dil_rate=8)
    net_body = create_block(net_body)
    classify = Conv2D(n_class,(1,1),activation='sigmoid') (net_body)
    
    #classify = Activation(activation='sigmoid') (net_body)
    #classify = Dense(1,activation='sigmoid') (net_body)

    model = Model(inputs=inputs, outputs=classify)
    model.compile(optimizer=Adam(0.001), loss=loss, metrics=[bce_dice_loss, dice_coef])

    return model

# %%
my_model = get_net()

# %%
print(my_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 20)      200
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 20)      3620
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 20)      3620
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 20)      3620
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 20)      3620
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 128, 20)      3620
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 20)      3620
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128, 128, 20)      80
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128, 128, 20)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 1)       21
# =================================================================
# Total params: 22,501
# Trainable params: 22,221
# Non-trainable params: 280
# _________________________________________________________________
# None

# %%
# Fit model

earlystopper = EarlyStopping(patience=12, verbose=1)
checkpointer = ModelCheckpoint(model_checkpoint_file, verbose=1, save_best_only=True)
reduce_plateau = ReduceLROnPlateau(monitor='val_loss', 
                           factor=0.2,
                           patience=4,
                           verbose=1,
                        #   min_lr=0.00001,
                            epsilon=0.001,
                           mode='auto') 

results = my_model.fit(train_X, train_Y, validation_split=0.1, batch_size=20, epochs=100, verbose=1, 
                       shuffle=True, callbacks=[ earlystopper, checkpointer, reduce_plateau])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.6407 - bce_dice_loss: 1.3271 - dice_coef: 0.4302
# Epoch 00001: val_loss improved from inf to 0.34051, saving model to meshnet_v4.h5
# 603/603 [==============================] - 285s 473ms/step - loss: 0.6410 - bce_dice_loss: 1.3284 - dice_coef: 0.4292 - val_loss: 0.3405 - val_bce_dice_loss: 0.8827 - val_dice_coef: 0.7231
# Epoch 2/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.4324 - bce_dice_loss: 1.0022 - dice_coef: 0.6824
# Epoch 00002: val_loss improved from 0.34051 to 0.33867, saving model to meshnet_v4.h5
# 603/603 [==============================] - 268s 445ms/step - loss: 0.4324 - bce_dice_loss: 1.0017 - dice_coef: 0.6823 - val_loss: 0.3387 - val_bce_dice_loss: 0.8394 - val_dice_coef: 0.6980
# Epoch 3/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.3327 - bce_dice_loss: 0.8331 - dice_coef: 0.7458
# Epoch 00003: val_loss did not improve
# 603/603 [==============================] - 283s 469ms/step - loss: 0.3330 - bce_dice_loss: 0.8348 - dice_coef: 0.7444 - val_loss: 0.4923 - val_bce_dice_loss: 1.0926 - val_dice_coef: 0.4859
# Epoch 4/100
# 600/603 [============================>.] - ETA: 13s - loss: 0.2613 - bce_dice_loss: 0.7106 - dice_coef: 0.7875
# Epoch 00004: val_loss improved from 0.33867 to 0.18653, saving model to meshnet_v4.h5
# 603/603 [==============================] - 2781s 5s/step - loss: 0.2620 - bce_dice_loss: 0.7117 - dice_coef: 0.7866 - val_loss: 0.1865 - val_bce_dice_loss: 0.5419 - val_dice_coef: 0.8119
# Epoch 5/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.2122 - bce_dice_loss: 0.6017 - dice_coef: 0.8205
# Epoch 00005: val_loss improved from 0.18653 to 0.18505, saving model to meshnet_v4.h5
# 603/603 [==============================] - 269s 445ms/step - loss: 0.2127 - bce_dice_loss: 0.6022 - dice_coef: 0.8200 - val_loss: 0.1851 - val_bce_dice_loss: 0.5487 - val_dice_coef: 0.8086
# Epoch 6/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1878 - bce_dice_loss: 0.5440 - dice_coef: 0.8262
# Epoch 00006: val_loss improved from 0.18505 to 0.12994, saving model to meshnet_v4.h5
# 603/603 [==============================] - 268s 445ms/step - loss: 0.1880 - bce_dice_loss: 0.5440 - dice_coef: 0.8262 - val_loss: 0.1299 - val_bce_dice_loss: 0.3896 - val_dice_coef: 0.8240
# Epoch 7/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1619 - bce_dice_loss: 0.4828 - dice_coef: 0.8428
# Epoch 00007: val_loss improved from 0.12994 to 0.11740, saving model to meshnet_v4.h5
# 603/603 [==============================] - 300s 498ms/step - loss: 0.1634 - bce_dice_loss: 0.4844 - dice_coef: 0.8420 - val_loss: 0.1174 - val_bce_dice_loss: 0.3522 - val_dice_coef: 0.8389
# Epoch 8/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1662 - bce_dice_loss: 0.4906 - dice_coef: 0.8153
# Epoch 00008: val_loss did not improve
# 603/603 [==============================] - 280s 465ms/step - loss: 0.1664 - bce_dice_loss: 0.4917 - dice_coef: 0.8149 - val_loss: 0.1270 - val_bce_dice_loss: 0.3797 - val_dice_coef: 0.8027
# Epoch 9/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1438 - bce_dice_loss: 0.4334 - dice_coef: 0.8371
# Epoch 00009: val_loss improved from 0.11740 to 0.10430, saving model to meshnet_v4.h5
# 603/603 [==============================] - 276s 458ms/step - loss: 0.1441 - bce_dice_loss: 0.4336 - dice_coef: 0.8369 - val_loss: 0.1043 - val_bce_dice_loss: 0.3260 - val_dice_coef: 0.8374
# Epoch 10/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1339 - bce_dice_loss: 0.4038 - dice_coef: 0.8456
# Epoch 00010: val_loss improved from 0.10430 to 0.10139, saving model to meshnet_v4.h5
# 603/603 [==============================] - 275s 456ms/step - loss: 0.1340 - bce_dice_loss: 0.4052 - dice_coef: 0.8450 - val_loss: 0.1014 - val_bce_dice_loss: 0.3080 - val_dice_coef: 0.8498
# Epoch 11/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1311 - bce_dice_loss: 0.3912 - dice_coef: 0.8417
# Epoch 00011: val_loss did not improve
# 603/603 [==============================] - 262s 434ms/step - loss: 0.1315 - bce_dice_loss: 0.3928 - dice_coef: 0.8408 - val_loss: 0.1070 - val_bce_dice_loss: 0.3290 - val_dice_coef: 0.8264
# Epoch 12/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1256 - bce_dice_loss: 0.3803 - dice_coef: 0.8440
# Epoch 00012: val_loss improved from 0.10139 to 0.10130, saving model to meshnet_v4.h5
# 603/603 [==============================] - 262s 435ms/step - loss: 0.1260 - bce_dice_loss: 0.3817 - dice_coef: 0.8433 - val_loss: 0.1013 - val_bce_dice_loss: 0.3027 - val_dice_coef: 0.8443
# Epoch 13/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1211 - bce_dice_loss: 0.3669 - dice_coef: 0.8465
# Epoch 00013: val_loss improved from 0.10130 to 0.09769, saving model to meshnet_v4.h5
# 603/603 [==============================] - 263s 437ms/step - loss: 0.1209 - bce_dice_loss: 0.3665 - dice_coef: 0.8468 - val_loss: 0.0977 - val_bce_dice_loss: 0.3013 - val_dice_coef: 0.8629
# Epoch 14/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1159 - bce_dice_loss: 0.3470 - dice_coef: 0.8534
# Epoch 00014: val_loss did not improve
# 603/603 [==============================] - 261s 432ms/step - loss: 0.1162 - bce_dice_loss: 0.3487 - dice_coef: 0.8524 - val_loss: 0.1002 - val_bce_dice_loss: 0.2973 - val_dice_coef: 0.8458
# Epoch 15/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1129 - bce_dice_loss: 0.3371 - dice_coef: 0.8567
# Epoch 00015: val_loss improved from 0.09769 to 0.09587, saving model to meshnet_v4.h5
# 603/603 [==============================] - 261s 433ms/step - loss: 0.1132 - bce_dice_loss: 0.3381 - dice_coef: 0.8562 - val_loss: 0.0959 - val_bce_dice_loss: 0.2879 - val_dice_coef: 0.8512
# Epoch 16/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1106 - bce_dice_loss: 0.3357 - dice_coef: 0.8539
# Epoch 00016: val_loss did not improve
# 603/603 [==============================] - 260s 432ms/step - loss: 0.1105 - bce_dice_loss: 0.3359 - dice_coef: 0.8538 - val_loss: 0.1050 - val_bce_dice_loss: 0.3069 - val_dice_coef: 0.8346
# Epoch 17/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1080 - bce_dice_loss: 0.3264 - dice_coef: 0.8557
# Epoch 00017: val_loss improved from 0.09587 to 0.09140, saving model to meshnet_v4.h5
# 603/603 [==============================] - 262s 435ms/step - loss: 0.1094 - bce_dice_loss: 0.3284 - dice_coef: 0.8547 - val_loss: 0.0914 - val_bce_dice_loss: 0.2775 - val_dice_coef: 0.8654
# Epoch 18/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1100 - bce_dice_loss: 0.3312 - dice_coef: 0.8538
# Epoch 00018: val_loss improved from 0.09140 to 0.08551, saving model to meshnet_v4.h5
# 603/603 [==============================] - 281s 465ms/step - loss: 0.1110 - bce_dice_loss: 0.3353 - dice_coef: 0.8507 - val_loss: 0.0855 - val_bce_dice_loss: 0.2731 - val_dice_coef: 0.8646
# Epoch 19/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1120 - bce_dice_loss: 0.3370 - dice_coef: 0.8498
# Epoch 00019: val_loss did not improve
# 603/603 [==============================] - 263s 436ms/step - loss: 0.1120 - bce_dice_loss: 0.3368 - dice_coef: 0.8499 - val_loss: 0.0894 - val_bce_dice_loss: 0.2795 - val_dice_coef: 0.8564
# Epoch 20/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1042 - bce_dice_loss: 0.3115 - dice_coef: 0.8611
# Epoch 00020: val_loss did not improve
# 603/603 [==============================] - 265s 439ms/step - loss: 0.1041 - bce_dice_loss: 0.3115 - dice_coef: 0.8612 - val_loss: 0.0938 - val_bce_dice_loss: 0.2869 - val_dice_coef: 0.8481
# Epoch 21/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0996 - bce_dice_loss: 0.3023 - dice_coef: 0.8642
# Epoch 00021: val_loss improved from 0.08551 to 0.08053, saving model to meshnet_v4.h5
# 603/603 [==============================] - 264s 437ms/step - loss: 0.0998 - bce_dice_loss: 0.3024 - dice_coef: 0.8642 - val_loss: 0.0805 - val_bce_dice_loss: 0.2467 - val_dice_coef: 0.8782
# Epoch 22/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1030 - bce_dice_loss: 0.3042 - dice_coef: 0.8640
# Epoch 00022: val_loss did not improve
# 603/603 [==============================] - 266s 442ms/step - loss: 0.1033 - bce_dice_loss: 0.3053 - dice_coef: 0.8635 - val_loss: 0.0835 - val_bce_dice_loss: 0.2514 - val_dice_coef: 0.8762
# Epoch 23/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0998 - bce_dice_loss: 0.3016 - dice_coef: 0.8625
# Epoch 00023: val_loss did not improve
# 603/603 [==============================] - 265s 439ms/step - loss: 0.1005 - bce_dice_loss: 0.3024 - dice_coef: 0.8622 - val_loss: 0.0863 - val_bce_dice_loss: 0.2682 - val_dice_coef: 0.8628
# Epoch 24/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0980 - bce_dice_loss: 0.2983 - dice_coef: 0.8654
# Epoch 00024: val_loss improved from 0.08053 to 0.07981, saving model to meshnet_v4.h5
# 603/603 [==============================] - 264s 438ms/step - loss: 0.0980 - bce_dice_loss: 0.2984 - dice_coef: 0.8655 - val_loss: 0.0798 - val_bce_dice_loss: 0.2460 - val_dice_coef: 0.8779
# Epoch 25/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0968 - bce_dice_loss: 0.2894 - dice_coef: 0.8688
# Epoch 00025: val_loss improved from 0.07981 to 0.07505, saving model to meshnet_v4.h5
# 603/603 [==============================] - 262s 435ms/step - loss: 0.0968 - bce_dice_loss: 0.2892 - dice_coef: 0.8689 - val_loss: 0.0751 - val_bce_dice_loss: 0.2371 - val_dice_coef: 0.8837
# Epoch 26/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0940 - bce_dice_loss: 0.2850 - dice_coef: 0.8709
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 264s 437ms/step - loss: 0.0940 - bce_dice_loss: 0.2855 - dice_coef: 0.8708 - val_loss: 0.0877 - val_bce_dice_loss: 0.2695 - val_dice_coef: 0.8607
# Epoch 27/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0953 - bce_dice_loss: 0.2869 - dice_coef: 0.8680
# Epoch 00027: val_loss did not improve
# 603/603 [==============================] - 262s 434ms/step - loss: 0.0953 - bce_dice_loss: 0.2865 - dice_coef: 0.8682 - val_loss: 0.0754 - val_bce_dice_loss: 0.2337 - val_dice_coef: 0.8848
# Epoch 28/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0971 - bce_dice_loss: 0.2943 - dice_coef: 0.8646
# Epoch 00028: val_loss did not improve
# 603/603 [==============================] - 264s 438ms/step - loss: 0.0970 - bce_dice_loss: 0.2943 - dice_coef: 0.8646 - val_loss: 0.0766 - val_bce_dice_loss: 0.2353 - val_dice_coef: 0.8819
# Epoch 29/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0949 - bce_dice_loss: 0.2854 - dice_coef: 0.8686
# Epoch 00029: val_loss did not improve
# 603/603 [==============================] - 263s 436ms/step - loss: 0.0951 - bce_dice_loss: 0.2854 - dice_coef: 0.8686 - val_loss: 0.0793 - val_bce_dice_loss: 0.2495 - val_dice_coef: 0.8742
# Epoch 30/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.1007 - bce_dice_loss: 0.3023 - dice_coef: 0.8595
# Epoch 00030: val_loss did not improve
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 603/603 [==============================] - 264s 438ms/step - loss: 0.1006 - bce_dice_loss: 0.3019 - dice_coef: 0.8597 - val_loss: 0.0823 - val_bce_dice_loss: 0.2520 - val_dice_coef: 0.8710
# Epoch 31/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0930 - bce_dice_loss: 0.2844 - dice_coef: 0.8708
# Epoch 00031: val_loss did not improve
# 603/603 [==============================] - 262s 434ms/step - loss: 0.0980 - bce_dice_loss: 0.2914 - dice_coef: 0.8684 - val_loss: 0.0806 - val_bce_dice_loss: 0.2511 - val_dice_coef: 0.8710
# Epoch 32/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0967 - bce_dice_loss: 0.2884 - dice_coef: 0.8709
# Epoch 00032: val_loss did not improve
# 603/603 [==============================] - 261s 433ms/step - loss: 0.0966 - bce_dice_loss: 0.2887 - dice_coef: 0.8709 - val_loss: 0.0774 - val_bce_dice_loss: 0.2538 - val_dice_coef: 0.8738
# Epoch 33/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0919 - bce_dice_loss: 0.2839 - dice_coef: 0.8714
# Epoch 00033: val_loss improved from 0.07505 to 0.07427, saving model to meshnet_v4.h5
# 603/603 [==============================] - 264s 439ms/step - loss: 0.0918 - bce_dice_loss: 0.2838 - dice_coef: 0.8714 - val_loss: 0.0743 - val_bce_dice_loss: 0.2395 - val_dice_coef: 0.8818
# Epoch 34/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0876 - bce_dice_loss: 0.2716 - dice_coef: 0.8775
# Epoch 00034: val_loss did not improve
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 603/603 [==============================] - 261s 433ms/step - loss: 0.0889 - bce_dice_loss: 0.2742 - dice_coef: 0.8761 - val_loss: 0.0750 - val_bce_dice_loss: 0.2395 - val_dice_coef: 0.8807
# Epoch 35/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0898 - bce_dice_loss: 0.2792 - dice_coef: 0.8749
# Epoch 00035: val_loss did not improve
# 603/603 [==============================] - 262s 435ms/step - loss: 0.0904 - bce_dice_loss: 0.2803 - dice_coef: 0.8743 - val_loss: 0.0747 - val_bce_dice_loss: 0.2384 - val_dice_coef: 0.8814
# Epoch 36/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0884 - bce_dice_loss: 0.2753 - dice_coef: 0.8758
# Epoch 00036: val_loss did not improve
# 603/603 [==============================] - 261s 432ms/step - loss: 0.0885 - bce_dice_loss: 0.2754 - dice_coef: 0.8757 - val_loss: 0.0745 - val_bce_dice_loss: 0.2382 - val_dice_coef: 0.8814
# Epoch 37/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0897 - bce_dice_loss: 0.2759 - dice_coef: 0.8754
# Epoch 00037: val_loss improved from 0.07427 to 0.07384, saving model to meshnet_v4.h5
# 603/603 [==============================] - 262s 434ms/step - loss: 0.0899 - bce_dice_loss: 0.2784 - dice_coef: 0.8735 - val_loss: 0.0738 - val_bce_dice_loss: 0.2360 - val_dice_coef: 0.8830
# Epoch 38/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0877 - bce_dice_loss: 0.2702 - dice_coef: 0.8787
# Epoch 00038: val_loss did not improve
# 603/603 [==============================] - 262s 435ms/step - loss: 0.0879 - bce_dice_loss: 0.2708 - dice_coef: 0.8783 - val_loss: 0.0739 - val_bce_dice_loss: 0.2363 - val_dice_coef: 0.8829
# Epoch 39/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0895 - bce_dice_loss: 0.2770 - dice_coef: 0.8751
# Epoch 00039: val_loss did not improve
# 603/603 [==============================] - 264s 438ms/step - loss: 0.0893 - bce_dice_loss: 0.2766 - dice_coef: 0.8754 - val_loss: 0.0743 - val_bce_dice_loss: 0.2375 - val_dice_coef: 0.8821
# Epoch 40/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0888 - bce_dice_loss: 0.2744 - dice_coef: 0.8759
# Epoch 00040: val_loss did not improve
# 603/603 [==============================] - 264s 438ms/step - loss: 0.0889 - bce_dice_loss: 0.2744 - dice_coef: 0.8759 - val_loss: 0.0739 - val_bce_dice_loss: 0.2363 - val_dice_coef: 0.8828
# Epoch 41/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0887 - bce_dice_loss: 0.2737 - dice_coef: 0.8770
# Epoch 00041: val_loss did not improve
# 603/603 [==============================] - 264s 438ms/step - loss: 0.0893 - bce_dice_loss: 0.2743 - dice_coef: 0.8767 - val_loss: 0.0739 - val_bce_dice_loss: 0.2358 - val_dice_coef: 0.8829
# Epoch 42/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0886 - bce_dice_loss: 0.2732 - dice_coef: 0.8767
# Epoch 00042: val_loss did not improve
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 603/603 [==============================] - 263s 436ms/step - loss: 0.0898 - bce_dice_loss: 0.2748 - dice_coef: 0.8759 - val_loss: 0.0738 - val_bce_dice_loss: 0.2358 - val_dice_coef: 0.8829
# Epoch 43/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0876 - bce_dice_loss: 0.2701 - dice_coef: 0.8784
# Epoch 00043: val_loss improved from 0.07384 to 0.07381, saving model to meshnet_v4.h5
# 603/603 [==============================] - 273s 453ms/step - loss: 0.0877 - bce_dice_loss: 0.2701 - dice_coef: 0.8785 - val_loss: 0.0738 - val_bce_dice_loss: 0.2358 - val_dice_coef: 0.8829
# Epoch 44/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0890 - bce_dice_loss: 0.2722 - dice_coef: 0.8774
# Epoch 00044: val_loss did not improve
# 603/603 [==============================] - 284s 471ms/step - loss: 0.0894 - bce_dice_loss: 0.2727 - dice_coef: 0.8771 - val_loss: 0.0738 - val_bce_dice_loss: 0.2359 - val_dice_coef: 0.8829
# Epoch 45/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0875 - bce_dice_loss: 0.2681 - dice_coef: 0.8795
# Epoch 00045: val_loss did not improve
# 603/603 [==============================] - 264s 437ms/step - loss: 0.0874 - bce_dice_loss: 0.2678 - dice_coef: 0.8797 - val_loss: 0.0739 - val_bce_dice_loss: 0.2359 - val_dice_coef: 0.8829
# Epoch 46/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0887 - bce_dice_loss: 0.2718 - dice_coef: 0.8772
# Epoch 00046: val_loss did not improve
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 603/603 [==============================] - 266s 441ms/step - loss: 0.0890 - bce_dice_loss: 0.2721 - dice_coef: 0.8769 - val_loss: 0.0739 - val_bce_dice_loss: 0.2359 - val_dice_coef: 0.8828
# Epoch 47/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0886 - bce_dice_loss: 0.2732 - dice_coef: 0.8760
# Epoch 00047: val_loss did not improve
# 603/603 [==============================] - 263s 436ms/step - loss: 0.0896 - bce_dice_loss: 0.2746 - dice_coef: 0.8755 - val_loss: 0.0740 - val_bce_dice_loss: 0.2359 - val_dice_coef: 0.8827
# Epoch 48/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0921 - bce_dice_loss: 0.2809 - dice_coef: 0.8737
# Epoch 00048: val_loss did not improve
# 603/603 [==============================] - 264s 437ms/step - loss: 0.0935 - bce_dice_loss: 0.2828 - dice_coef: 0.8729 - val_loss: 0.0741 - val_bce_dice_loss: 0.2361 - val_dice_coef: 0.8825
# Epoch 49/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0882 - bce_dice_loss: 0.2717 - dice_coef: 0.8773
# Epoch 00049: val_loss did not improve
# 603/603 [==============================] - 263s 436ms/step - loss: 0.0886 - bce_dice_loss: 0.2722 - dice_coef: 0.8770 - val_loss: 0.0740 - val_bce_dice_loss: 0.2359 - val_dice_coef: 0.8826
# Epoch 50/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0873 - bce_dice_loss: 0.2704 - dice_coef: 0.8777
# Epoch 00050: val_loss did not improve
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 603/603 [==============================] - 278s 461ms/step - loss: 0.0893 - bce_dice_loss: 0.2731 - dice_coef: 0.8768 - val_loss: 0.0740 - val_bce_dice_loss: 0.2360 - val_dice_coef: 0.8826
# Epoch 51/100
# 600/603 [============================>.] - ETA: 1s - loss: 0.0891 - bce_dice_loss: 0.2724 - dice_coef: 0.8775
# Epoch 00051: val_loss did not improve
# 603/603 [==============================] - 271s 450ms/step - loss: 0.0896 - bce_dice_loss: 0.2732 - dice_coef: 0.8770 - val_loss: 0.0740 - val_bce_dice_loss: 0.2361 - val_dice_coef: 0.8826
# Epoch 52/100
# 380/603 [=================>............] - ETA: 1:39 - loss: 0.0918 - bce_dice_loss: 0.2843 - dice_coef: 0.8712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e796f659e4ae> in <module>()
#      12
#      13 results = my_model.fit(train_X, train_Y, validation_split=0.1, batch_size=20, epochs=100, verbose=1,
# ---> 14                        shuffle=True, callbacks=[ earlystopper, checkpointer, reduce_plateau])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1667                               initial_epoch=initial_epoch,
#    1668                               steps_per_epoch=steps_per_epoch,
# -> 1669                               validation_steps=validation_steps)
#    1670
#    1671     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1204                         ins_batch[i] = ins_batch[i].toarray()
#    1205
# -> 1206                     outs = f(ins_batch)
#    1207                     if not isinstance(outs, list):
#    1208                         outs = [outs]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
## Import Test Data and Make Predictions with Model

# Import images (either test or training)
# Decolorize, resize, store in array, and save filenames, etc.
def import_images(root):
    dirs = os.listdir(root)
    filenames=[os.path.join(root,file_id) + "/images/"+file_id+".png" for file_id in dirs]
    images=[imread(imagefile,as_grey=True) for imagefile in filenames]
    resized_images = [ img_as_ubyte(resize(image,(img_width,img_height))) for image in images] 
    Array = np.reshape(np.array(resized_images),(len(resized_images),img_height,img_width,1))
    return Array, resized_images, images, filenames, dirs


    

test_dirs = os.listdir(test_root)
test_filenames=[os.path.join(test_root,file_id) + "/images/"+file_id+".png" for file_id in test_dirs]
test_images=[imread(imagefile,as_grey=True) for imagefile in test_filenames]
resized_test_images = [ img_as_ubyte(resize(image,(img_width,img_height))) for image in test_images] 
test_X = np.reshape(np.array(resized_test_images),(len(resized_test_images),img_height,img_width,1))

final_model = load_model(model_checkpoint_file, custom_objects={'dice_coef': dice_coef, 'bce_dice_loss':bce_dice_loss})
preds_test = final_model.predict(test_X, verbose=1)

preds_test_t = (preds_test > 0.5) 

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (test_images[i].shape[0], test_images[i].shape[1]), 
                                       mode='constant', preserve_range=True))

preds_test_upsampled_bool = [ (mask > 0.5).astype(bool) for mask in preds_test_upsampled ]
# Out:
# 65/65 [==============================] - 21s 324ms/step

# %%
plot_check([test_images,preds_test_upsampled,preds_test_upsampled_bool],rand_imgs=2)

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

def generate_prediction_file(image_names,predictions,filename):
    new_test_ids = []
    rles = []
    for n, id_ in enumerate(image_names):
        rle = list(prob_to_rles(predictions[n]))
        rles.extend(rle)
        new_test_ids.extend([id_] * len(rle))
    sub = pd.DataFrame()
    sub['ImageId'] = new_test_ids
    sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
    sub.to_csv(filename, index=False)

# %%
generate_prediction_file(test_dirs,preds_test_upsampled_bool,'meshnetv4_mesh_pred.csv')

# %% [markdown]
# Ideas
#  - Experiment with compression of training data. Am I preserving as much detail
#     as I can in dtype np.uint8 (values of 0 to 255) ?
# - Color vs B&W?
# - Combine mask and prediction images to show false positives and negatives
# - What is the best resizing method? Reflect??
# - Put computer vision / threshold method output as an input to neural net
# - Output intermediate layers for inspection
# - Crop images to train networks faster for testing ??
# - Take random crops of images to create, and then combine outputs in the end
# - Is combining the masks really the best thing to do? Should I be keeping the individual cells separate?
# - Pseudo-labelled data
