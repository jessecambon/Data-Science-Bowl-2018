# %% [markdown]
# Source: https://www.kaggle.com/ahassaine/pure-image-processing-lb-0-274/code

# %% [markdown]
# **Reading data**

# %%
import os
#import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.util import img_as_bool, img_as_uint, img_as_ubyte
from skimage.transform import resize
#import skimage
#import glob
import random
#from random import randint, shuffle

from keras import regularizers
from keras.models import Model, load_model
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization, add, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras.losses import binary_crossentropy

model_checkpoint_file='bw_model_v3.h5'

# Root folders for test and training data
train_root = "./stage1_train"
test_root = "./stage1_test"

# Size we resize all images to
image_size = (128,128)

img_height
img_width =

# %%
## Import Training Data Images 
train_dirs = os.listdir(train_root)
train_filenames=[os.path.join(train_root,file_id) + "/images/"+file_id+".png" for file_id in train_dirs]
# Convert to B&W inline
#train_images=[cv2.cvtColor(cv2.imread(imagefile),cv2.COLOR_BGR2GRAY) for imagefile in train_filenames]
train_images=[img_as_ubyte(imread(imagefile,as_grey=True)) for imagefile in train_filenames]

# Use this instead if you want color images
#train_images=[imread(imagefile) for imagefile in train_filenames]
# Out:
# C:\Users\jesse\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
## Import Training Masks

# This function creates a single combined mask image 
# when given a list of masks
# Probably a computationally faster way to do this...
def collapse_masks(mask_list):
    for i, mask_file in enumerate(mask_list):        
        if i != 0:
            # combine mask with previous mask in list 
            mask = np.maximum(mask, img_as_bool(imread(os.path.join(train_root,mask_file))))
        else:
            # read first mask in
            mask = img_as_bool(imread(os.path.join(train_root,mask_file)))
    
    return mask

# Import all the masks
train_mask_dirs = [ os.path.join(path, 'masks') for path in os.listdir(train_root) ]
train_mask_files = [ [os.path.join(dir,file) for file in os.listdir(os.path.join(train_root,dir)) ]  for dir in train_mask_dirs]

#def collapse_masks(mask_list):
#    for i, mask_file in enumerate(mask_list):
#        print(i)
#        print(mask_file)
        
#testing = [collapse_masks(mask_files) for mask_files in train_mask_files]

# Divide output of each mask by 255 to make a 1/0 binary mask
train_mask_images = [ collapse_masks(mask_files) for mask_files in train_mask_files ]
# Out:
# C:\Users\jesse\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from uint8 to bool
#   .format(dtypeobj_in, dtypeobj_out))

# %%
train_mask_images[0].min()
# Out:
# False

# %%
# Plot a training test and mask image side by side
def plot_side_by_side(image_ds,mask_ds,image_num):
    print('Image #: ' + str(image_num) + '. Image Sizes: ' + str(image_ds[image_num].shape) + ' ' + str(mask_ds[image_num].shape))
    fig = plt.figure(figsize=(10,10))
    ax1 = fig.add_subplot(1,2,1)
    ax1.imshow(image_ds[image_num])
    ax2 = fig.add_subplot(1,2,2)
    ax2.imshow(mask_ds[image_num])
    plt.show()
    
# Plots random corresponding images and masks
def plot_check(images,masks,display_num):
    for i in range(display_num):
        plot_side_by_side(images,masks,randint(0,len(images)))
    
#plot_side_by_side(train_images,train_mask_images,38)
# Plot a few random images 
plot_check(train_images,train_mask_images,5)
# Out:
# Image #: 275. Image Sizes: (256, 256) (256, 256)
# Image #: 308. Image Sizes: (256, 320) (256, 320)
# Image #: 360. Image Sizes: (256, 256) (256, 256)
# Image #: 24. Image Sizes: (256, 256) (256, 256)
# Image #: 135. Image Sizes: (256, 256) (256, 256)

# %%
# Resize everything
resized_train_images = [ img_as_ubyte(resize(image,image_size,mode='constant')) for image in train_images] 
resized_train_mask_images = [ img_as_bool(resize(image,image_size,mode='constant')) for image in train_mask_images]
# Out:
# C:\Users\jesse\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\jesse\Anaconda3\lib\site-packages\skimage\util\dtype.py:118: UserWarning: Possible sign loss when converting negative image of type float64 to positive image of type bool.
#   .format(dtypeobj_in, dtypeobj_out))
# C:\Users\jesse\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to bool
#   .format(dtypeobj_in, dtypeobj_out))

# %%
# Plot some resized images
plot_check(resized_train_images,resized_train_mask_images,5)
# Out:
# Image #: 2. Image Sizes: (128, 128) (128, 128)
# Image #: 640. Image Sizes: (128, 128) (128, 128)
# Image #: 151. Image Sizes: (128, 128) (128, 128)
# Image #: 213. Image Sizes: (128, 128) (128, 128)
# Image #: 72. Image Sizes: (128, 128) (128, 128)

# %%
# Shuffle images and masks in same way (so that they still correspond)
# This might be redundant since you can do in the model fit stage

#all_train = list(zip(resized_train_images,resized_train_mask_images))
#random.shuffle(all_train)
#shuffled_train_images, shuffled_train_mask_images = zip(*all_train)

# %%
# Reshape model inputs
train_X = np.reshape(np.array(resized_train_images),(670,128,128,1))
train_Y = (np.reshape(np.array(resized_train_mask_images),(670,128,128,1)))

# Check size of arrays we are inputting to model
print(train_X.shape)
print(train_Y.shape)
print(train_X.nbytes)
print(train_Y.nbytes)
# Out:
# (670, 128, 128, 1)
# (670, 128, 128, 1)
# 10977280
# 10977280

# %%
train_images[0].max()
#train_X[0]
# Out:
# 108

# %%
plot_side_by_side(np.squeeze(train_X,axis=3),np.squeeze(train_Y,axis=3),100)
plot_side_by_side(train_images,train_mask_images,100)
# Out:
# Image #: 100. Image Sizes: (128, 128) (128, 128)
# Image #: 100. Image Sizes: (256, 256) (256, 256)

# %% [markdown]
# # Now Let's Build a Neural Net

# %%
# Loss and metric functions for the neural net
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def create_block(x, filters=20, filter_size=(3, 3), activation='relu',dil_rate=(1,1),dropout_rate=0.2):
#    for i in range(n_block):
    x = Conv2D(filters, filter_size, padding='same', dilation_rate = dil_rate) (x)
    x = Activation('relu') (x)
    x = BatchNormalization() (x) 
    x = Dropout(dropout_rate) (x)
    return x


## master function for creating a net
def get_net(
        input_shape=(128, 128,1),
        num_filters=20,
        lr=0.01,
        loss=bce_dice_loss,
        n_class=1
):
    inputs = Input(input_shape)
    
    # Create layers
    net_body = create_block(inputs)
    net_body = create_block(net_body)
    net_body = create_block(net_body)
    net_body = create_block(net_body,dil_rate=(2,2))
    net_body = create_block(net_body)
    net_body = create_block(net_body)
    # Sigmoid used since we are classifying pixels 1/0. Softmax used for multiclass
    classify = Conv2D(1,(1,1),activation='sigmoid')(net_body)

    model = Model(inputs=inputs, outputs=classify)
    model.compile(optimizer=Adam(lr), loss=loss, metrics=[dice_coef, binary_crossentropy])

    return model

# %%
my_model = get_net()

# %%
print(my_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 256, 256, 1)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 256, 256, 20)      200
# _________________________________________________________________
# activation_13 (Activation)   (None, 256, 256, 20)      0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 256, 256, 20)      80
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256, 256, 20)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 256, 256, 20)      3620
# _________________________________________________________________
# activation_14 (Activation)   (None, 256, 256, 20)      0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 256, 256, 20)      80
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256, 256, 20)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 256, 256, 20)      3620
# _________________________________________________________________
# activation_15 (Activation)   (None, 256, 256, 20)      0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 256, 256, 20)      80
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256, 256, 20)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 256, 256, 20)      3620
# _________________________________________________________________
# activation_16 (Activation)   (None, 256, 256, 20)      0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256, 256, 20)      80
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256, 256, 20)      0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 256, 256, 20)      3620
# _________________________________________________________________
# activation_17 (Activation)   (None, 256, 256, 20)      0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256, 256, 20)      80
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256, 256, 20)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 256, 256, 20)      3620
# _________________________________________________________________
# activation_18 (Activation)   (None, 256, 256, 20)      0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256, 256, 20)      80
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 256, 256, 20)      0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 256, 256, 1)       21
# =================================================================
# Total params: 18,801
# Trainable params: 18,561
# Non-trainable params: 240
# _________________________________________________________________
# None

# %%
# Fit model

# Implement learning rate decay https://keras.io/callbacks/#learningratescheduler 

earlystopper = EarlyStopping(patience=6, verbose=1)
checkpointer = ModelCheckpoint(model_checkpoint_file, verbose=1, save_best_only=True)
reduce_plateau = ReduceLROnPlateau(monitor='val_loss', 
                           factor=0.5,
                           patience=3,
                           verbose=1,
                           mode='auto') 
# verbose=2 => one line per epoch, 1 = progress bar
results = my_model.fit(train_X, train_Y, validation_split=0.1, batch_size=15, epochs=50, verbose=1 , shuffle=True,
                    callbacks=[earlystopper, checkpointer, reduce_plateau])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.9253 - dice_coef: 0.6190 - binary_crossentropy: 0.4110
# Epoch 00001: val_loss improved from inf to 0.65384, saving model to bw_model_v3.h5
# 603/603 [==============================] - 237s 394ms/step - loss: 0.9276 - dice_coef: 0.6174 - binary_crossentropy: 0.4122 - val_loss: 0.6538 - val_dice_coef: 0.6976 - val_binary_crossentropy: 0.3192
# Epoch 2/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.6022 - dice_coef: 0.7007 - binary_crossentropy: 0.2511
# Epoch 00002: val_loss improved from 0.65384 to 0.60951, saving model to bw_model_v3.h5
# 603/603 [==============================] - 233s 387ms/step - loss: 0.6049 - dice_coef: 0.6998 - binary_crossentropy: 0.2531 - val_loss: 0.6095 - val_dice_coef: 0.7359 - val_binary_crossentropy: 0.3323
# Epoch 3/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.4739 - dice_coef: 0.7612 - binary_crossentropy: 0.1878
# Epoch 00003: val_loss improved from 0.60951 to 0.49830, saving model to bw_model_v3.h5
# 603/603 [==============================] - 242s 401ms/step - loss: 0.4813 - dice_coef: 0.7588 - binary_crossentropy: 0.1931 - val_loss: 0.4983 - val_dice_coef: 0.7592 - val_binary_crossentropy: 0.2513
# Epoch 4/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.4447 - dice_coef: 0.7733 - binary_crossentropy: 0.1767
# Epoch 00004: val_loss improved from 0.49830 to 0.38724, saving model to bw_model_v3.h5
# 603/603 [==============================] - 233s 386ms/step - loss: 0.4493 - dice_coef: 0.7706 - binary_crossentropy: 0.1788 - val_loss: 0.3872 - val_dice_coef: 0.8020 - val_binary_crossentropy: 0.1761
# Epoch 5/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3685 - dice_coef: 0.8160 - binary_crossentropy: 0.1471
# Epoch 00005: val_loss did not improve
# 603/603 [==============================] - 238s 395ms/step - loss: 0.3693 - dice_coef: 0.8153 - binary_crossentropy: 0.1472 - val_loss: 0.5229 - val_dice_coef: 0.7503 - val_binary_crossentropy: 0.2593
# Epoch 6/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3752 - dice_coef: 0.8121 - binary_crossentropy: 0.1540
# Epoch 00006: val_loss did not improve
# 603/603 [==============================] - 237s 393ms/step - loss: 0.3782 - dice_coef: 0.8109 - binary_crossentropy: 0.1559 - val_loss: 0.4203 - val_dice_coef: 0.7990 - val_binary_crossentropy: 0.1898
# Epoch 7/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3505 - dice_coef: 0.8231 - binary_crossentropy: 0.1405
# Epoch 00007: val_loss improved from 0.38724 to 0.35649, saving model to bw_model_v3.h5
# 603/603 [==============================] - 225s 374ms/step - loss: 0.3526 - dice_coef: 0.8222 - binary_crossentropy: 0.1417 - val_loss: 0.3565 - val_dice_coef: 0.8132 - val_binary_crossentropy: 0.1549
# Epoch 8/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3698 - dice_coef: 0.8136 - binary_crossentropy: 0.1471
# Epoch 00008: val_loss improved from 0.35649 to 0.34598, saving model to bw_model_v3.h5
# 603/603 [==============================] - 237s 392ms/step - loss: 0.3717 - dice_coef: 0.8131 - binary_crossentropy: 0.1485 - val_loss: 0.3460 - val_dice_coef: 0.8250 - val_binary_crossentropy: 0.1580
# Epoch 9/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.4199 - dice_coef: 0.7867 - binary_crossentropy: 0.1726
# Epoch 00009: val_loss did not improve
# 603/603 [==============================] - 242s 401ms/step - loss: 0.4221 - dice_coef: 0.7847 - binary_crossentropy: 0.1728 - val_loss: 0.5339 - val_dice_coef: 0.7222 - val_binary_crossentropy: 0.2510
# Epoch 10/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3372 - dice_coef: 0.8310 - binary_crossentropy: 0.1337
# Epoch 00010: val_loss did not improve
# 603/603 [==============================] - 235s 389ms/step - loss: 0.3409 - dice_coef: 0.8298 - binary_crossentropy: 0.1363 - val_loss: 0.3732 - val_dice_coef: 0.8096 - val_binary_crossentropy: 0.1688
# Epoch 11/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3166 - dice_coef: 0.8420 - binary_crossentropy: 0.1258
# Epoch 00011: val_loss improved from 0.34598 to 0.31638, saving model to bw_model_v3.h5
# 603/603 [==============================] - 227s 376ms/step - loss: 0.3166 - dice_coef: 0.8419 - binary_crossentropy: 0.1257 - val_loss: 0.3164 - val_dice_coef: 0.8370 - val_binary_crossentropy: 0.1371
# Epoch 12/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3192 - dice_coef: 0.8400 - binary_crossentropy: 0.1317
# Epoch 00012: val_loss did not improve
# 603/603 [==============================] - 219s 364ms/step - loss: 0.3228 - dice_coef: 0.8382 - binary_crossentropy: 0.1336 - val_loss: 0.4001 - val_dice_coef: 0.7808 - val_binary_crossentropy: 0.1704
# Epoch 13/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3275 - dice_coef: 0.8352 - binary_crossentropy: 0.1317
# Epoch 00013: val_loss did not improve
# 603/603 [==============================] - 231s 384ms/step - loss: 0.3270 - dice_coef: 0.8354 - binary_crossentropy: 0.1316 - val_loss: 0.3889 - val_dice_coef: 0.7948 - val_binary_crossentropy: 0.1704
# Epoch 14/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3048 - dice_coef: 0.8483 - binary_crossentropy: 0.1242
# Epoch 00014: val_loss improved from 0.31638 to 0.31238, saving model to bw_model_v3.h5
# 603/603 [==============================] - 222s 368ms/step - loss: 0.3069 - dice_coef: 0.8472 - binary_crossentropy: 0.1254 - val_loss: 0.3124 - val_dice_coef: 0.8395 - val_binary_crossentropy: 0.1251
# Epoch 15/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3056 - dice_coef: 0.8475 - binary_crossentropy: 0.1231
# Epoch 00015: val_loss improved from 0.31238 to 0.30792, saving model to bw_model_v3.h5
# 603/603 [==============================] - 225s 374ms/step - loss: 0.3055 - dice_coef: 0.8477 - binary_crossentropy: 0.1232 - val_loss: 0.3079 - val_dice_coef: 0.8413 - val_binary_crossentropy: 0.1232
# Epoch 16/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3102 - dice_coef: 0.8449 - binary_crossentropy: 0.1276
# Epoch 00016: val_loss did not improve
# 603/603 [==============================] - 216s 357ms/step - loss: 0.3099 - dice_coef: 0.8451 - binary_crossentropy: 0.1274 - val_loss: 0.3168 - val_dice_coef: 0.8359 - val_binary_crossentropy: 0.1343
# Epoch 17/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3058 - dice_coef: 0.8459 - binary_crossentropy: 0.1242
# Epoch 00017: val_loss improved from 0.30792 to 0.27944, saving model to bw_model_v3.h5
# 603/603 [==============================] - 215s 357ms/step - loss: 0.3080 - dice_coef: 0.8452 - binary_crossentropy: 0.1257 - val_loss: 0.2794 - val_dice_coef: 0.8556 - val_binary_crossentropy: 0.1221
# Epoch 18/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3202 - dice_coef: 0.8416 - binary_crossentropy: 0.1316
# Epoch 00018: val_loss did not improve
# 603/603 [==============================] - 215s 357ms/step - loss: 0.3208 - dice_coef: 0.8411 - binary_crossentropy: 0.1316 - val_loss: 0.3752 - val_dice_coef: 0.8053 - val_binary_crossentropy: 0.1715
# Epoch 19/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2995 - dice_coef: 0.8507 - binary_crossentropy: 0.1236
# Epoch 00019: val_loss did not improve
# 603/603 [==============================] - 215s 357ms/step - loss: 0.3027 - dice_coef: 0.8498 - binary_crossentropy: 0.1260 - val_loss: 0.3347 - val_dice_coef: 0.8243 - val_binary_crossentropy: 0.1374
# Epoch 20/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.3029 - dice_coef: 0.8488 - binary_crossentropy: 0.1213
# Epoch 00020: val_loss did not improve
# 603/603 [==============================] - 213s 354ms/step - loss: 0.3027 - dice_coef: 0.8488 - binary_crossentropy: 0.1210 - val_loss: 0.3158 - val_dice_coef: 0.8277 - val_binary_crossentropy: 0.1175
# Epoch 21/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2971 - dice_coef: 0.8524 - binary_crossentropy: 0.1229
# Epoch 00021: val_loss did not improve
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 603/603 [==============================] - 215s 356ms/step - loss: 0.2978 - dice_coef: 0.8520 - binary_crossentropy: 0.1231 - val_loss: 0.2980 - val_dice_coef: 0.8454 - val_binary_crossentropy: 0.1286
# Epoch 22/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2702 - dice_coef: 0.8653 - binary_crossentropy: 0.1087
# Epoch 00022: val_loss improved from 0.27944 to 0.27374, saving model to bw_model_v3.h5
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2704 - dice_coef: 0.8653 - binary_crossentropy: 0.1088 - val_loss: 0.2737 - val_dice_coef: 0.8548 - val_binary_crossentropy: 0.1088
# Epoch 23/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2671 - dice_coef: 0.8665 - binary_crossentropy: 0.1084
# Epoch 00023: val_loss improved from 0.27374 to 0.26380, saving model to bw_model_v3.h5
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2669 - dice_coef: 0.8667 - binary_crossentropy: 0.1084 - val_loss: 0.2638 - val_dice_coef: 0.8650 - val_binary_crossentropy: 0.1058
# Epoch 24/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2686 - dice_coef: 0.8660 - binary_crossentropy: 0.1093
# Epoch 00024: val_loss did not improve
# 603/603 [==============================] - 213s 353ms/step - loss: 0.2696 - dice_coef: 0.8655 - binary_crossentropy: 0.1100 - val_loss: 0.3013 - val_dice_coef: 0.8430 - val_binary_crossentropy: 0.1296
# Epoch 25/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2617 - dice_coef: 0.8705 - binary_crossentropy: 0.1072
# Epoch 00025: val_loss did not improve
# 603/603 [==============================] - 213s 352ms/step - loss: 0.2623 - dice_coef: 0.8699 - binary_crossentropy: 0.1072 - val_loss: 0.2832 - val_dice_coef: 0.8485 - val_binary_crossentropy: 0.1135
# Epoch 26/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2595 - dice_coef: 0.8712 - binary_crossentropy: 0.1059
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2602 - dice_coef: 0.8710 - binary_crossentropy: 0.1063 - val_loss: 0.2706 - val_dice_coef: 0.8574 - val_binary_crossentropy: 0.1097
# Epoch 27/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2560 - dice_coef: 0.8734 - binary_crossentropy: 0.1041
# Epoch 00027: val_loss did not improve
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 603/603 [==============================] - 213s 353ms/step - loss: 0.2569 - dice_coef: 0.8731 - binary_crossentropy: 0.1047 - val_loss: 0.2645 - val_dice_coef: 0.8589 - val_binary_crossentropy: 0.1063
# Epoch 28/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2544 - dice_coef: 0.8743 - binary_crossentropy: 0.1040
# Epoch 00028: val_loss improved from 0.26380 to 0.24969, saving model to bw_model_v3.h5
# 603/603 [==============================] - 214s 354ms/step - loss: 0.2543 - dice_coef: 0.8743 - binary_crossentropy: 0.1039 - val_loss: 0.2497 - val_dice_coef: 0.8691 - val_binary_crossentropy: 0.0995
# Epoch 29/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2500 - dice_coef: 0.8756 - binary_crossentropy: 0.1016
# Epoch 00029: val_loss did not improve
# 603/603 [==============================] - 213s 354ms/step - loss: 0.2519 - dice_coef: 0.8749 - binary_crossentropy: 0.1028 - val_loss: 0.2644 - val_dice_coef: 0.8595 - val_binary_crossentropy: 0.1058
# Epoch 30/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2551 - dice_coef: 0.8733 - binary_crossentropy: 0.1031
# Epoch 00030: val_loss did not improve
# 603/603 [==============================] - 213s 353ms/step - loss: 0.2562 - dice_coef: 0.8725 - binary_crossentropy: 0.1034 - val_loss: 0.2548 - val_dice_coef: 0.8646 - val_binary_crossentropy: 0.0999
# Epoch 31/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2485 - dice_coef: 0.8761 - binary_crossentropy: 0.0998
# Epoch 00031: val_loss did not improve
# 603/603 [==============================] - 214s 354ms/step - loss: 0.2502 - dice_coef: 0.8755 - binary_crossentropy: 0.1009 - val_loss: 0.2628 - val_dice_coef: 0.8612 - val_binary_crossentropy: 0.1064
# Epoch 32/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2479 - dice_coef: 0.8769 - binary_crossentropy: 0.0990
# Epoch 00032: val_loss did not improve
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2486 - dice_coef: 0.8768 - binary_crossentropy: 0.0996 - val_loss: 0.2589 - val_dice_coef: 0.8632 - val_binary_crossentropy: 0.1062
# Epoch 33/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2497 - dice_coef: 0.8754 - binary_crossentropy: 0.1012
# Epoch 00033: val_loss did not improve
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2497 - dice_coef: 0.8756 - binary_crossentropy: 0.1013 - val_loss: 0.2546 - val_dice_coef: 0.8651 - val_binary_crossentropy: 0.1028
# Epoch 34/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2422 - dice_coef: 0.8804 - binary_crossentropy: 0.0978
# Epoch 00034: val_loss improved from 0.24969 to 0.24142, saving model to bw_model_v3.h5
# 603/603 [==============================] - 212s 351ms/step - loss: 0.2456 - dice_coef: 0.8784 - binary_crossentropy: 0.0993 - val_loss: 0.2414 - val_dice_coef: 0.8730 - val_binary_crossentropy: 0.0970
# Epoch 35/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2472 - dice_coef: 0.8772 - binary_crossentropy: 0.0985
# Epoch 00035: val_loss did not improve
# 603/603 [==============================] - 213s 353ms/step - loss: 0.2483 - dice_coef: 0.8769 - binary_crossentropy: 0.0993 - val_loss: 0.2462 - val_dice_coef: 0.8705 - val_binary_crossentropy: 0.0992
# Epoch 36/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2446 - dice_coef: 0.8792 - binary_crossentropy: 0.0993
# Epoch 00036: val_loss did not improve
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2446 - dice_coef: 0.8792 - binary_crossentropy: 0.0993 - val_loss: 0.2553 - val_dice_coef: 0.8648 - val_binary_crossentropy: 0.1035
# Epoch 37/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2525 - dice_coef: 0.8756 - binary_crossentropy: 0.1038
# Epoch 00037: val_loss did not improve
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2521 - dice_coef: 0.8759 - binary_crossentropy: 0.1036 - val_loss: 0.2449 - val_dice_coef: 0.8708 - val_binary_crossentropy: 0.0988
# Epoch 38/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2427 - dice_coef: 0.8800 - binary_crossentropy: 0.0987
# Epoch 00038: val_loss did not improve
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 603/603 [==============================] - 214s 354ms/step - loss: 0.2421 - dice_coef: 0.8803 - binary_crossentropy: 0.0984 - val_loss: 0.2440 - val_dice_coef: 0.8714 - val_binary_crossentropy: 0.0983
# Epoch 39/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2509 - dice_coef: 0.8756 - binary_crossentropy: 0.1019
# Epoch 00039: val_loss did not improve
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2515 - dice_coef: 0.8754 - binary_crossentropy: 0.1023 - val_loss: 0.2509 - val_dice_coef: 0.8669 - val_binary_crossentropy: 0.1020
# Epoch 40/50
# 600/603 [============================>.] - ETA: 1s - loss: 0.2404 - dice_coef: 0.8813 - binary_crossentropy: 0.0980
# Epoch 00040: val_loss did not improve
# 603/603 [==============================] - 212s 352ms/step - loss: 0.2410 - dice_coef: 0.8812 - binary_crossentropy: 0.0983 - val_loss: 0.2573 - val_dice_coef: 0.8639 - val_binary_crossentropy: 0.1056
# Epoch 00040: early stopping

# %%
Ideas
 - Experiment with compression of training data. Am I preserving as much detail
    as I can in dtype np.uint8 (values of 0 to 255) ?
- Color vs B&W?
- Crop images to train networks faster for testing ??
- Is combining the masks really the best thing to do? Should I be keeping the individual cells separate?
- Pseudo-labelled data
