# %% [markdown]
# MeshNet architecture based on https://arxiv.org/pdf/1612.00940.pdf
#
# "End-to-end learning of brain tissue segmentation
# from imperfect labeling"
# Jun 2017
# Alex Fedorov∗†, Jeremy Johnson‡
# , Eswar Damaraju∗†, Alexei Ozerin§
# , Vince Calhoun∗†, Sergey Plis∗†

# %% [markdown]
# # Libraries and Global Parameters

# %%
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.util import img_as_bool, img_as_uint, img_as_ubyte, img_as_int
from skimage.transform import resize
from skimage.morphology import label
import random
from random import randint 
from keras import regularizers
from keras.models import Model, load_model
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, Dense, \
    UpSampling2D, BatchNormalization, add, Dropout, Flatten
from keras.layers.core import Lambda
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
from keras import backend as K
from keras.losses import binary_crossentropy, sparse_categorical_crossentropy


####### UPDATE THIS #########
#############################

model_num = 13

#############################
#############################

model_checkpoint_file= 'meshnet_v' + str(model_num) +'.h5'
submission_filename = 'meshnet_v' + str(model_num) +'_mesh_pred.csv'

# Root folders for test and training data
train_root = "./stage1_train"
test_root = "./stage1_test"

# Size we resize all images to
#image_size = (128,128)

img_height = 128
img_width = 128
img_channels = 1 # 1 for B&W, 3 for RGB

import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
#warnings.resetwarnings()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Preparing the Data

# %%
# Import images (either test or training)
# Decolorize, resize, store in array, and save filenames, etc.
def import_images(root):
    dirs = os.listdir(root)
    filenames=[os.path.join(root,file_id) + "/images/"+file_id+".png" for file_id in dirs]
    images=[imread(imagefile,as_grey=True) for imagefile in filenames]
    resized_images = [ resize(image,(img_width,img_height)) for image in images] 
    Array = np.reshape(np.array(resized_images),
                       (len(resized_images),img_height,img_width,img_channels))
    #Array = np.reshape(np.array(img_as_ubyte(resized_images),dtype=np.uint8).astype(np.uint8),
    #                   (len(resized_images),img_height,img_width,img_channels))
    
    print(Array.mean())
    print(Array.std())

    # Normalize inputs
    Array = ((Array - Array.mean())/Array.std())

    print(Array.mean())
    print(Array.std())
    print(images[0].dtype)
    print(resized_images[0].dtype)
    print(Array[0,0,0,0].dtype)
    return Array, resized_images, images, filenames, dirs

train_X, resized_train_images, \
train_images, train_filenames, train_dirs = import_images(train_root)
# Out:
# 0.160902796657
# 0.249621650769
# 1.26292011674e-15
# 1.0
# float64
# float64
# float64

# %%
np.finfo(np.longdouble)
# Out:
# finfo(resolution=1e-15, min=-1.7976931348623157e+308, max=1.7976931348623157e+308, dtype=float64)

# %%
## Import Training Masks
# this takes longer than the training images because we have to
# combine a lot of mask files

# This function creates a single combined mask image 
# when given a list of masks
# Probably a computationally faster way to do this...
def collapse_masks(mask_list):
    for i, mask_file in enumerate(mask_list):        
        if i != 0:
            # combine mask with previous mask in list 
            mask = np.maximum(mask, imread(os.path.join(train_root,mask_file)))
        else:
            # read first mask in
            mask = imread(os.path.join(train_root,mask_file))
    
    return mask

# Import all the masks
train_mask_dirs = [ os.path.join(path, 'masks') for path in os.listdir(train_root) ]
train_mask_files = [ [os.path.join(dir,file) for file in os.listdir(os.path.join(train_root,dir)) ]  for dir in train_mask_dirs]
train_masks = [ collapse_masks(mask_files) for mask_files in train_mask_files ]
resized_train_masks = [ img_as_bool(resize(image,(img_width,img_height))) for image in train_masks] 
train_Y = np.reshape(np.array(resized_train_masks),(len(resized_train_masks),img_height,img_width,img_channels))

# %%
# Plot images side by side for a list of datasets
def plot_side_by_side(ds_list,image_num,size=(15,10)):
    print('Image #: ' + str(image_num))
    fig = plt.figure(figsize=size)

    for i in range(len(ds_list)):
        ax1 = fig.add_subplot(1,len(ds_list),i+1)
        ax1.imshow(ds_list[i][image_num])

    plt.show()
    
# Plots random corresponding images and masks
def plot_check(ds_list,rand_imgs=None,img_nums=None,size=(15,10)):
    if rand_imgs != None:
        for i in range(rand_imgs):
            plot_side_by_side(ds_list, randint(0,len(ds_list[0])-1),size=size)
    if img_nums != None:
        for i in range(len(img_nums)):
            plot_side_by_side(ds_list,img_nums[i],size=size)
    

plot_check([train_images,train_masks],rand_imgs=1,size=(10,7))
# Out:
# Image #: 341

# %%
# Check size of arrays we are inputting to model
# This is important! We need the datasets to be as 
# small as possible to reduce computation time

# Check physical size
print(train_X.shape)
print(train_Y.shape)

# Check memory size
print(train_X.nbytes)
print(train_Y.nbytes)

# Check datatypes
print(train_X.dtype)
print(train_Y.dtype)
# Out:
# (670, 128, 128, 1)
# (670, 128, 128, 1)
# 87818240
# 10977280
# float64
# bool

# %%
plot_check([resized_train_images,np.squeeze(train_X,axis=3)],rand_imgs=1,size=(10,7))
# Out:
# Image #: 569

# %% [markdown]
# # Now Let's Build the Model

# %%
# Loss and metric functions for the neural net
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def create_block(x, filters=21, filter_size=(3, 3), activation='relu',dil_rate=1,dropout_rate=0.25):
    x = Conv2D(filters, filter_size, padding='same', activation=activation, dilation_rate = dil_rate) (x)
   # x = BatchNormalization() (x) 
    x = Dropout(dropout_rate) (x)
    return x


## master function for creating a net
def get_net(
        input_shape=(img_height, img_width,img_channels),
        loss=binary_crossentropy,
        lr=0.001,
        n_class=1,
        nb_filters=21,
        dropout_rate=0.2
):
    
    inputs = Input(input_shape)
    
    # Does this help with computation?? 

    # Create layers
    net_body = create_block(inputs,filters=nb_filters,dropout_rate=dropout_rate)
    net_body = create_block(inputs,filters=nb_filters,dropout_rate=dropout_rate)
    net_body = create_block(net_body,filters=nb_filters,dropout_rate=dropout_rate,dil_rate=2)
    net_body = create_block(net_body,filters=nb_filters,dropout_rate=dropout_rate,dil_rate=6)
    net_body = create_block(net_body,filters=nb_filters,dropout_rate=dropout_rate,dil_rate=12)
    net_body = create_block(net_body,filters=nb_filters,dropout_rate=dropout_rate,dil_rate=20)
    net_body = create_block(net_body,filters=nb_filters,dropout_rate=dropout_rate)
    classify = Conv2D(n_class,(1,1),activation='sigmoid') (net_body)

    model = Model(inputs=inputs, outputs=classify)
    
    model.compile(optimizer=Adam(lr), loss=loss, metrics=[bce_dice_loss, dice_coef])

    return model

#### CREATE MODEL ##########################################################

my_model = get_net(nb_filters=30,dropout_rate=0.1,loss=binary_crossentropy)

############################################################################

print(my_model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 128, 128, 1)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 128, 128, 30)      300
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 128, 128, 30)      0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 128, 128, 30)      8130
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128, 128, 30)      0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 128, 128, 30)      8130
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128, 128, 30)      0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 128, 128, 30)      8130
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128, 128, 30)      0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 128, 128, 30)      8130
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128, 128, 30)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 128, 128, 30)      8130
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 128, 128, 30)      0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 128, 128, 1)       31
# =================================================================
# Total params: 40,981
# Trainable params: 40,981
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Fit model

earlystopper = EarlyStopping(patience=10, verbose=1)
checkpointer = ModelCheckpoint(model_checkpoint_file, verbose=1, save_best_only=True)
reduce_plateau = ReduceLROnPlateau(monitor='val_loss', 
                           factor=0.2,
                           patience=4,
                           verbose=1,
                        #   min_lr=0.00001,
                            epsilon=0.001,
                           mode='auto') 

results = my_model.fit(train_X, train_Y, validation_split=0.1, batch_size=1, epochs=100, verbose=1, 
                       shuffle=True, callbacks=[ earlystopper, checkpointer, reduce_plateau])
# Out:
# Train on 603 samples, validate on 67 samples
# Epoch 1/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.3074 - bce_dice_loss: 0.9873 - dice_coef: 0.2935
# Epoch 00001: val_loss improved from inf to 0.13340, saving model to meshnet_v13.h5
# 603/603 [==============================] - 297s 493ms/step - loss: 0.3075 - bce_dice_loss: 0.9869 - dice_coef: 0.2943 - val_loss: 0.1334 - val_bce_dice_loss: 0.4776 - val_dice_coef: 0.7713
# Epoch 2/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.1305 - bce_dice_loss: 0.4468 - dice_coef: 0.7956
# Epoch 00002: val_loss improved from 0.13340 to 0.12385, saving model to meshnet_v13.h5
# 603/603 [==============================] - 299s 496ms/step - loss: 0.1303 - bce_dice_loss: 0.4463 - dice_coef: 0.7958 - val_loss: 0.1238 - val_bce_dice_loss: 0.3200 - val_dice_coef: 0.8480
# Epoch 3/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.1109 - bce_dice_loss: 0.3773 - dice_coef: 0.8243
# Epoch 00003: val_loss improved from 0.12385 to 0.12287, saving model to meshnet_v13.h5
# 603/603 [==============================] - 303s 503ms/step - loss: 0.1107 - bce_dice_loss: 0.3769 - dice_coef: 0.8245 - val_loss: 0.1229 - val_bce_dice_loss: 0.3270 - val_dice_coef: 0.8460
# Epoch 4/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0997 - bce_dice_loss: 0.3401 - dice_coef: 0.8365
# Epoch 00004: val_loss improved from 0.12287 to 0.09523, saving model to meshnet_v13.h5
# 603/603 [==============================] - 307s 510ms/step - loss: 0.0997 - bce_dice_loss: 0.3399 - dice_coef: 0.8367 - val_loss: 0.0952 - val_bce_dice_loss: 0.2737 - val_dice_coef: 0.8720
# Epoch 5/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0942 - bce_dice_loss: 0.3189 - dice_coef: 0.8447
# Epoch 00005: val_loss did not improve
# 603/603 [==============================] - 299s 495ms/step - loss: 0.0941 - bce_dice_loss: 0.3187 - dice_coef: 0.8448 - val_loss: 0.1425 - val_bce_dice_loss: 0.4040 - val_dice_coef: 0.7812
# Epoch 6/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0950 - bce_dice_loss: 0.3218 - dice_coef: 0.8425
# Epoch 00006: val_loss improved from 0.09523 to 0.09333, saving model to meshnet_v13.h5
# 603/603 [==============================] - 305s 505ms/step - loss: 0.0949 - bce_dice_loss: 0.3219 - dice_coef: 0.8425 - val_loss: 0.0933 - val_bce_dice_loss: 0.3630 - val_dice_coef: 0.8395
# Epoch 7/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0906 - bce_dice_loss: 0.3060 - dice_coef: 0.8521
# Epoch 00007: val_loss improved from 0.09333 to 0.07744, saving model to meshnet_v13.h5
# 603/603 [==============================] - 296s 491ms/step - loss: 0.0905 - bce_dice_loss: 0.3057 - dice_coef: 0.8522 - val_loss: 0.0774 - val_bce_dice_loss: 0.2590 - val_dice_coef: 0.8762
# Epoch 8/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0898 - bce_dice_loss: 0.2999 - dice_coef: 0.8533
# Epoch 00008: val_loss improved from 0.07744 to 0.07684, saving model to meshnet_v13.h5
# 603/603 [==============================] - 292s 484ms/step - loss: 0.0897 - bce_dice_loss: 0.2996 - dice_coef: 0.8535 - val_loss: 0.0768 - val_bce_dice_loss: 0.2662 - val_dice_coef: 0.8615
# Epoch 9/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0853 - bce_dice_loss: 0.2877 - dice_coef: 0.8582
# Epoch 00009: val_loss improved from 0.07684 to 0.07482, saving model to meshnet_v13.h5
# 603/603 [==============================] - 293s 486ms/step - loss: 0.0852 - bce_dice_loss: 0.2875 - dice_coef: 0.8583 - val_loss: 0.0748 - val_bce_dice_loss: 0.2456 - val_dice_coef: 0.8798
# Epoch 10/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0835 - bce_dice_loss: 0.2788 - dice_coef: 0.8619
# Epoch 00010: val_loss did not improve
# 603/603 [==============================] - 291s 483ms/step - loss: 0.0836 - bce_dice_loss: 0.2789 - dice_coef: 0.8620 - val_loss: 0.0787 - val_bce_dice_loss: 0.2845 - val_dice_coef: 0.8515
# Epoch 11/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0846 - bce_dice_loss: 0.2876 - dice_coef: 0.8587
# Epoch 00011: val_loss did not improve
# 603/603 [==============================] - 290s 482ms/step - loss: 0.0845 - bce_dice_loss: 0.2873 - dice_coef: 0.8588 - val_loss: 0.0785 - val_bce_dice_loss: 0.2278 - val_dice_coef: 0.8862
# Epoch 12/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0808 - bce_dice_loss: 0.2726 - dice_coef: 0.8659
# Epoch 00012: val_loss improved from 0.07482 to 0.07383, saving model to meshnet_v13.h5
# 603/603 [==============================] - 287s 477ms/step - loss: 0.0808 - bce_dice_loss: 0.2725 - dice_coef: 0.8659 - val_loss: 0.0738 - val_bce_dice_loss: 0.2297 - val_dice_coef: 0.8810
# Epoch 13/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0805 - bce_dice_loss: 0.2734 - dice_coef: 0.8647
# Epoch 00013: val_loss did not improve
# 603/603 [==============================] - 291s 482ms/step - loss: 0.0805 - bce_dice_loss: 0.2731 - dice_coef: 0.8648 - val_loss: 0.0745 - val_bce_dice_loss: 0.2215 - val_dice_coef: 0.8890
# Epoch 14/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0772 - bce_dice_loss: 0.2606 - dice_coef: 0.8692
# Epoch 00014: val_loss did not improve
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 603/603 [==============================] - 290s 481ms/step - loss: 0.0778 - bce_dice_loss: 0.2615 - dice_coef: 0.8690 - val_loss: 0.0934 - val_bce_dice_loss: 0.2857 - val_dice_coef: 0.8496
# Epoch 15/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0712 - bce_dice_loss: 0.2479 - dice_coef: 0.8777
# Epoch 00015: val_loss improved from 0.07383 to 0.07084, saving model to meshnet_v13.h5
# 603/603 [==============================] - 289s 479ms/step - loss: 0.0712 - bce_dice_loss: 0.2477 - dice_coef: 0.8777 - val_loss: 0.0708 - val_bce_dice_loss: 0.2254 - val_dice_coef: 0.8845
# Epoch 16/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0688 - bce_dice_loss: 0.2372 - dice_coef: 0.8806
# Epoch 00016: val_loss improved from 0.07084 to 0.06898, saving model to meshnet_v13.h5
# 603/603 [==============================] - 290s 482ms/step - loss: 0.0688 - bce_dice_loss: 0.2374 - dice_coef: 0.8805 - val_loss: 0.0690 - val_bce_dice_loss: 0.2239 - val_dice_coef: 0.8892
# Epoch 17/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0679 - bce_dice_loss: 0.2342 - dice_coef: 0.8826
# Epoch 00017: val_loss improved from 0.06898 to 0.06617, saving model to meshnet_v13.h5
# 603/603 [==============================] - 290s 480ms/step - loss: 0.0678 - bce_dice_loss: 0.2340 - dice_coef: 0.8827 - val_loss: 0.0662 - val_bce_dice_loss: 0.2132 - val_dice_coef: 0.8945
# Epoch 18/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0672 - bce_dice_loss: 0.2344 - dice_coef: 0.8825
# Epoch 00018: val_loss did not improve
# 603/603 [==============================] - 291s 482ms/step - loss: 0.0675 - bce_dice_loss: 0.2348 - dice_coef: 0.8823 - val_loss: 0.0687 - val_bce_dice_loss: 0.2110 - val_dice_coef: 0.8926
# Epoch 19/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0676 - bce_dice_loss: 0.2343 - dice_coef: 0.8817
# Epoch 00019: val_loss did not improve
# 603/603 [==============================] - 290s 482ms/step - loss: 0.0675 - bce_dice_loss: 0.2342 - dice_coef: 0.8817 - val_loss: 0.0680 - val_bce_dice_loss: 0.2117 - val_dice_coef: 0.8906
# Epoch 20/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0669 - bce_dice_loss: 0.2317 - dice_coef: 0.8827
# Epoch 00020: val_loss did not improve
# 603/603 [==============================] - 290s 481ms/step - loss: 0.0668 - bce_dice_loss: 0.2315 - dice_coef: 0.8828 - val_loss: 0.0672 - val_bce_dice_loss: 0.2101 - val_dice_coef: 0.8931
# Epoch 21/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0667 - bce_dice_loss: 0.2321 - dice_coef: 0.8828
# Epoch 00021: val_loss did not improve
# 603/603 [==============================] - 289s 480ms/step - loss: 0.0667 - bce_dice_loss: 0.2321 - dice_coef: 0.8828 - val_loss: 0.0670 - val_bce_dice_loss: 0.2149 - val_dice_coef: 0.8878
# Epoch 22/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0663 - bce_dice_loss: 0.2300 - dice_coef: 0.8837
# Epoch 00022: val_loss did not improve
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 603/603 [==============================] - 290s 481ms/step - loss: 0.0663 - bce_dice_loss: 0.2299 - dice_coef: 0.8839 - val_loss: 0.0671 - val_bce_dice_loss: 0.2116 - val_dice_coef: 0.8905
# Epoch 23/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0644 - bce_dice_loss: 0.2257 - dice_coef: 0.8860
# Epoch 00023: val_loss improved from 0.06617 to 0.06606, saving model to meshnet_v13.h5
# 603/603 [==============================] - 286s 473ms/step - loss: 0.0643 - bce_dice_loss: 0.2255 - dice_coef: 0.8861 - val_loss: 0.0661 - val_bce_dice_loss: 0.2081 - val_dice_coef: 0.8940
# Epoch 24/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0642 - bce_dice_loss: 0.2243 - dice_coef: 0.8863
# Epoch 00024: val_loss improved from 0.06606 to 0.06517, saving model to meshnet_v13.h5
# 603/603 [==============================] - 284s 470ms/step - loss: 0.0641 - bce_dice_loss: 0.2242 - dice_coef: 0.8863 - val_loss: 0.0652 - val_bce_dice_loss: 0.2096 - val_dice_coef: 0.8930
# Epoch 25/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0641 - bce_dice_loss: 0.2248 - dice_coef: 0.8865
# Epoch 00025: val_loss did not improve
# 603/603 [==============================] - 286s 474ms/step - loss: 0.0641 - bce_dice_loss: 0.2247 - dice_coef: 0.8864 - val_loss: 0.0661 - val_bce_dice_loss: 0.2089 - val_dice_coef: 0.8924
# Epoch 26/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0638 - bce_dice_loss: 0.2235 - dice_coef: 0.8860
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 285s 472ms/step - loss: 0.0639 - bce_dice_loss: 0.2235 - dice_coef: 0.8861 - val_loss: 0.0665 - val_bce_dice_loss: 0.2125 - val_dice_coef: 0.8902
# Epoch 27/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0639 - bce_dice_loss: 0.2238 - dice_coef: 0.8864
# Epoch 00027: val_loss did not improve
# 603/603 [==============================] - 284s 472ms/step - loss: 0.0638 - bce_dice_loss: 0.2236 - dice_coef: 0.8865 - val_loss: 0.0663 - val_bce_dice_loss: 0.2102 - val_dice_coef: 0.8917
# Epoch 28/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0639 - bce_dice_loss: 0.2231 - dice_coef: 0.8870
# Epoch 00028: val_loss did not improve
# 603/603 [==============================] - 285s 472ms/step - loss: 0.0638 - bce_dice_loss: 0.2231 - dice_coef: 0.8870 - val_loss: 0.0663 - val_bce_dice_loss: 0.2115 - val_dice_coef: 0.8905
# Epoch 29/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0637 - bce_dice_loss: 0.2230 - dice_coef: 0.8869
# Epoch 00029: val_loss improved from 0.06517 to 0.06502, saving model to meshnet_v13.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 603/603 [==============================] - 286s 475ms/step - loss: 0.0637 - bce_dice_loss: 0.2229 - dice_coef: 0.8870 - val_loss: 0.0650 - val_bce_dice_loss: 0.2094 - val_dice_coef: 0.8924
# Epoch 30/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0632 - bce_dice_loss: 0.2230 - dice_coef: 0.8873
# Epoch 00030: val_loss did not improve
# 603/603 [==============================] - 285s 473ms/step - loss: 0.0633 - bce_dice_loss: 0.2230 - dice_coef: 0.8873 - val_loss: 0.0657 - val_bce_dice_loss: 0.2090 - val_dice_coef: 0.8923
# Epoch 31/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0632 - bce_dice_loss: 0.2222 - dice_coef: 0.8876
# Epoch 00031: val_loss did not improve
# 603/603 [==============================] - 287s 477ms/step - loss: 0.0632 - bce_dice_loss: 0.2220 - dice_coef: 0.8878 - val_loss: 0.0658 - val_bce_dice_loss: 0.2086 - val_dice_coef: 0.8923
# Epoch 32/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0632 - bce_dice_loss: 0.2217 - dice_coef: 0.8872
# Epoch 00032: val_loss did not improve
# 603/603 [==============================] - 290s 480ms/step - loss: 0.0632 - bce_dice_loss: 0.2217 - dice_coef: 0.8872 - val_loss: 0.0655 - val_bce_dice_loss: 0.2086 - val_dice_coef: 0.8923
# Epoch 33/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0633 - bce_dice_loss: 0.2219 - dice_coef: 0.8873
# Epoch 00033: val_loss did not improve
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 603/603 [==============================] - 284s 471ms/step - loss: 0.0632 - bce_dice_loss: 0.2218 - dice_coef: 0.8874 - val_loss: 0.0654 - val_bce_dice_loss: 0.2082 - val_dice_coef: 0.8928
# Epoch 34/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0630 - bce_dice_loss: 0.2215 - dice_coef: 0.8877
# Epoch 00034: val_loss did not improve
# 603/603 [==============================] - 282s 468ms/step - loss: 0.0632 - bce_dice_loss: 0.2218 - dice_coef: 0.8876 - val_loss: 0.0656 - val_bce_dice_loss: 0.2082 - val_dice_coef: 0.8927
# Epoch 35/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0632 - bce_dice_loss: 0.2216 - dice_coef: 0.8878
# Epoch 00035: val_loss did not improve
# 603/603 [==============================] - 281s 466ms/step - loss: 0.0631 - bce_dice_loss: 0.2214 - dice_coef: 0.8878 - val_loss: 0.0657 - val_bce_dice_loss: 0.2083 - val_dice_coef: 0.8926
# Epoch 36/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0629 - bce_dice_loss: 0.2212 - dice_coef: 0.8877
# Epoch 00036: val_loss did not improve
# 603/603 [==============================] - 284s 470ms/step - loss: 0.0630 - bce_dice_loss: 0.2213 - dice_coef: 0.8877 - val_loss: 0.0658 - val_bce_dice_loss: 0.2085 - val_dice_coef: 0.8925
# Epoch 37/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0632 - bce_dice_loss: 0.2217 - dice_coef: 0.8876
# Epoch 00037: val_loss did not improve
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 603/603 [==============================] - 283s 469ms/step - loss: 0.0631 - bce_dice_loss: 0.2216 - dice_coef: 0.8877 - val_loss: 0.0658 - val_bce_dice_loss: 0.2084 - val_dice_coef: 0.8926
# Epoch 38/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0629 - bce_dice_loss: 0.2213 - dice_coef: 0.8873
# Epoch 00038: val_loss did not improve
# 603/603 [==============================] - 287s 476ms/step - loss: 0.0631 - bce_dice_loss: 0.2214 - dice_coef: 0.8872 - val_loss: 0.0658 - val_bce_dice_loss: 0.2084 - val_dice_coef: 0.8926
# Epoch 39/100
# 602/603 [============================>.] - ETA: 0s - loss: 0.0631 - bce_dice_loss: 0.2212 - dice_coef: 0.8877
# Epoch 00039: val_loss did not improve
# 603/603 [==============================] - 289s 480ms/step - loss: 0.0631 - bce_dice_loss: 0.2211 - dice_coef: 0.8878 - val_loss: 0.0658 - val_bce_dice_loss: 0.2084 - val_dice_coef: 0.8926
# Epoch 00039: early stopping

# %%
for val_loss in results.history['val_loss']:
    print(round(val_loss,3))
#print(results.history)
# Out:
# 0.133
# 0.124
# 0.123
# 0.095
# 0.143
# 0.093
# 0.077
# 0.077
# 0.075
# 0.079
# 0.078
# 0.074
# 0.075
# 0.093
# 0.071
# 0.069
# 0.066
# 0.069
# 0.068
# 0.067
# 0.067
# 0.067
# 0.066
# 0.065
# 0.066
# 0.067
# 0.066
# 0.066
# 0.065
# 0.066
# 0.066
# 0.066
# 0.065
# 0.066
# 0.066
# 0.066
# 0.066
# 0.066
# 0.066

# %%
## Import Test Data and Make Predictions with Model

# Import images (either test or training)
# Decolorize, resize, store in array, and save filenames, etc.
test_X, resized_test_images, \
test_images, test_filenames, test_dirs = import_images(test_root)


# Load model and make predictions on test data
final_model = load_model(model_checkpoint_file, custom_objects={'dice_coef': dice_coef, 'bce_dice_loss':bce_dice_loss})
preds_test = final_model.predict(test_X, verbose=1)

preds_test_t = (preds_test > 0.5) 

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (test_images[i].shape[0], test_images[i].shape[1]), 
                                       mode='constant', preserve_range=True))

preds_test_upsampled_bool = [ (mask > 0.5).astype(bool) for mask in preds_test_upsampled ]
# Out:
# 0.208730805725
# 0.293186881966
# 1.75073630806e-16
# 1.0
# float64
# float64
# float64
# 65/65 [==============================] - 15s 236ms/step

# %%
plot_check([test_images,preds_test_upsampled,preds_test_upsampled_bool],rand_imgs=2)
# Out:
# Image #: 23
# Image #: 40

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

        
def generate_prediction_file(image_names,predictions,filename):
    new_test_ids = []
    rles = []
    for n, id_ in enumerate(image_names):
        rle = list(prob_to_rles(predictions[n]))
        rles.extend(rle)
        new_test_ids.extend([id_] * len(rle))
    sub = pd.DataFrame()
    sub['ImageId'] = new_test_ids
    sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
    sub.to_csv(filename, index=False)

# %%
generate_prediction_file(test_dirs,preds_test_upsampled_bool,submission_filename)

# %% [markdown]
# Ideas
#  - Experiment with compression of training data. Am I preserving as much detail
#     as I can in dtype np.uint8 (values of 0 to 255) ?
# - Color vs B&W?
# - Combine mask and prediction images to show false positives and negatives
# - What is the best resizing method? Reflect??
# - Put computer vision / threshold method output as an input to neural net
# - Output intermediate layers for inspection
# - Crop images to train networks faster for testing ??
# - Take random crops of images to create, and then combine outputs in the end
# - Is combining the masks really the best thing to do? Should I be keeping the individual cells separate?
# - Pseudo-labelled data
